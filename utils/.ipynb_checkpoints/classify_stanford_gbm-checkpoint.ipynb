# %%
import os

import re
import csv

import numpy as np
import pandas as pd

import dicom
from collections import Counter

import shutil

from data_utils import arr_to_im_path

# %%
# helper functions - same as in classify_rtog
# TODO: put these functions in separate file

types_of_scan = ['MR', 'CT', 'PR']
AXIAL_VIEWS = ['axl', 'axial', 'ax']
SAGITAL_VIEWS = ['sag', 'sagital']
CORONAL_VIEWS = ['cor', 'coronal']
MODALITIES = ['t1', 't2', 'flair', 'dwi', 'gre', 'blade', 'propeller', 'lava', 'fame', 'mprage']
# mprage instead of rage, otherwise match on 'average'


def find_view(description):
    description = description.lower()
    if any(x in description for x in AXIAL_VIEWS):
        view = 'axial'
    elif any(x in description for x in SAGITAL_VIEWS):
        view = 'sagital'
    elif any(x in description for x in CORONAL_VIEWS):
        view = 'coronal'
    else:
        view = 'N/A'
    return view


def find_modality(description):
    description = description.lower()
    modalities = [x for x in MODALITIES if x in description]
    if len(modalities) == 0:
        modality = 'N/A'
    elif len(modalities) == 1:
        if 't1' in modalities:
            if 'pre' in description:
                modality = 't1pre'
            elif any(x in description for x in ['post', 't1c', '+c', '+ c', 'c+', 'con', 'gd', 'gad']):
                modality = 't1post'
            else:
                modality = 't1 pre or post?'
        else:
            modality = modalities[0]
    else:
        if set(modalities) == set(['flair', 't2']):
            modality = 'flair'
        else:
            modality = 'multiple modalities detected'

    return modality


def collect_info_patient_folder(patient_folder):  
    dicoms = os.listdir(patient_folder)
    dicoms = [dic for dic in dicoms if dic[-4:] == '.dcm']
    sample = dicoms[0]
    sample = os.path.join(patient_folder, sample)
    sample = dicom.read_file(sample)

    # collect information
    patient_id = str(sample.PatientName)
    date = str(sample.AcquisitionDate)
    thickness = str(sample.SliceThickness)
    rows = int(sample.Rows)
    columns = int(sample.Columns)
    nb_dicoms = len(dicoms)
    description = str(sample.SeriesDescription)
    view = find_view(description)
    modality = find_modality(description)

    return patient_id, view, modality, date, thickness, rows, columns, nb_dicoms, description

# %%
data_dir = '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM'

# get the patient folders to classify
all_files_path = []
for patient in os.listdir(data_dir): 
    patient_path = os.path.join(data_dir, patient)
    if os.path.isdir(patient_path):
        folders = os.listdir(patient_path)
        folders = [os.path.join(patient_path, fold) for fold in folders]
        folders = [fold for fold in folders if os.path.isdir(fold)]
        patient_path = os.path.join(patient_path, folders[0])
        folders = folders = os.listdir(patient_path)
        folders = [os.path.join(patient_path, fold) for fold in folders]
        folders = [fold for fold in folders if os.path.isdir(fold)]
        all_files_path.extend(folders)

# %%
csv_path = '/home/romains/stanford_gbm.csv'

# %%
# save csv on disk to export to speadsheet after and check results
with open(csv_path, 'w') as csvfile:
    fieldnames = ['id', 'description', 'view', 'modality',\
                  'nb_dicoms', 'date', 'thickness', 'rows', 'columns', 'raw']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for k, folder in enumerate(all_files_path):
        if k % 300 == 0:
            print('file %d out of %d'%(k + 1, len(all_files_path)))
        try:
            patient_id, view, modality, date, thickness, rows,\
                columns, nb_dicoms, description = collect_info_patient_folder(folder)
        except:
            continue
        writer.writerow({'id': patient_id, 'description': description,\
                         'view': view, 'modality': modality, 'nb_dicoms': nb_dicoms,\
                         'date': date, 'thickness': thickness, 'rows': rows,\
                         'columns': columns, 'raw': folder})
# Out:
# file 1 out of 2315
# file 301 out of 2315
# file 601 out of 2315
# file 901 out of 2315
# file 1201 out of 2315
# file 1501 out of 2315
# file 1801 out of 2315
# file 2101 out of 2315

# %%
# load csv to run some analyses on the number of patients for each view/modality
df = pd.read_csv(csv_path)

# drop any row for which view is not axial
df3 = df.replace('sagital', pd.np.nan)
df3 = df3.replace('coronal', pd.np.nan)
df3 = df3.dropna(axis=0, how='any')

# %%
df
# Out:
#               id                                        description     view  \
# 0     Patient-01                                  3D ASL with color      NaN
# 1     Patient-01                                   3Plane Loc SSFSE      NaN
# 2     Patient-01             Apparent Diffusion Coefficient (mm2/s)      NaN
# 3     Patient-01             Apparent Diffusion Coefficient (mm2/s)      NaN
# 4     Patient-01                                        Ax BRAVO +C    axial
# 5     Patient-01                                  Ax DWI (freq r/l)    axial
# 6     Patient-01                                           AX FLAIR    axial
# 7     Patient-01                                             Ax GRE    axial
# 8     Patient-01                                       AX T1 SE  +C    axial
# 9     Patient-01                                       AX T1 SE PRE    axial
# 10    Patient-01                                              AX T2    axial
# 11    Patient-01                        Cerebral Blood Flow (color)      NaN
# 12    Patient-01                                       COR BRAVO +C  coronal
# 13    Patient-01                                            COR DWI  coronal
# 14    Patient-01                                          COR FLAIR  coronal
# 15    Patient-01         Exponential Apparent Diffusion Coefficient      NaN
# 16    Patient-01         Exponential Apparent Diffusion Coefficient      NaN
# 17    Patient-01                                       SAG BRAVO +C  sagital
# 18    Patient-01                             Sag CUBE FLAIR (PROMO)  sagital
# 19    Patient-01                                 SAG FLAIR REFORMAT  sagital
# 20    Patient-01                                       Sag T1 FLAIR  sagital
# 21    Patient-02                                  3D ASL with color      NaN
# 22    Patient-02                                   3Plane Loc SSFSE      NaN
# 23    Patient-02             Apparent Diffusion Coefficient (mm2/s)      NaN
# 24    Patient-02                                  Ax DWI (freq r/l)    axial
# 25    Patient-02                                           AX FLAIR    axial
# 26    Patient-02                           Ax FSPGR BRAVO stereo +C    axial
# 27    Patient-02                                             Ax GRE    axial
# 28    Patient-02                                       AX T1 SE  +C    axial
# 29    Patient-02                                       AX T1 SE PRE    axial
# ...          ...                                                ...      ...
# 2170  Patient-98         Exponential Apparent Diffusion Coefficient      NaN
# 2171  Patient-98          RAPID AIF/VOF Locations (marked red/blue)      NaN
# 2172  Patient-98                                 RAPID AIF/VOF Plot      NaN
# 2173  Patient-98                                          RAPID CBF      NaN
# 2174  Patient-98                                          RAPID CBV      NaN
# 2175  Patient-98                                    RAPID Color CBF      NaN
# 2176  Patient-98                                    RAPID Color CBV      NaN
# 2177  Patient-98                                RAPID Color MTT [s]      NaN
# 2178  Patient-98                               RAPID Color TMax [s]    axial
# 2179  Patient-98                 RAPID Columned DWI and PWI Summary      NaN
# 2180  Patient-98  RAPID DWI and PWI Mismatch Lesion Sizes (colored)      NaN
# 2181  Patient-98                                      RAPID MTT [s]      NaN
# 2182  Patient-98                                     RAPID TMax [s]    axial
# 2183  Patient-98                                          SAG FLAIR  sagital
# 2184  Patient-98                                             SAG T1  sagital
# 2185  Patient-98                                        SAG T1 POST  sagital
# 2186  Patient-99                                      3-plane SSFSE      NaN
# 2187  Patient-99                                      3PL SSFSE LOC      NaN
# 2188  Patient-99             Apparent Diffusion Coefficient (mm?/s)      NaN
# 2189  Patient-99                                       AX DIFFUSION    axial
# 2190  Patient-99                                     AX T1 POST F.S    axial
# 2191  Patient-99                                  AX T1 POST STEREO    axial
# 2192  Patient-99                                          AX T1 PRE    axial
# 2193  Patient-99                                    COR T1 POST F.S  coronal
# 2194  Patient-99         Exponential Apparent Diffusion Coefficient      NaN
# 2195  Patient-99                                             SAG T1  sagital
# 2196  Patient-99                                       T2 COR FLAIR  coronal
# 2197  Patient-99                                           T2 FLAIR      NaN
# 2198  Patient-99                                        T2 FSE  3MM      NaN
# 2199  Patient-99                                         T2* AX GRE    axial
#
#                           modality  nb_dicoms      date  thickness  rows  \
# 0                              NaN         72  20151126        4.0   128
# 1                              NaN         30  20151126       10.0   512
# 2                              NaN         30  20151126        5.0   256
# 3                              NaN         38  20151126        5.0   256
# 4                              NaN        172  20151126        1.0   256
# 5                              dwi         60  20151126        5.0   256
# 6                            flair         52  20151126        5.0   512
# 7                              gre         30  20151126        5.0   512
# 8                           t1post         30  20151126        5.0   512
# 9                            t1pre         30  20151126        5.0   512
# 10                              t2         30  20151126        5.0   512
# 11                             NaN         36  20151126        4.0   244
# 12                             NaN        121  20151126        2.0   512
# 13                             dwi         76  20151126        5.0   256
# 14                           flair         52  20151126        5.0   512
# 15                             NaN         30  20151126        5.0   256
# 16                             NaN         38  20151126        5.0   256
# 17                             NaN        121  20151126        2.0   512
# 18                           flair        272  20151126        1.2   512
# 19                           flair         34  20151126        5.0   512
# 20    multiple modalities detected         27  20151126        4.0   512
# 21                             NaN         58  20160124        4.0   128
# 22                             NaN         30  20160124       10.0   512
# 23                             NaN         32  20160124        5.0   256
# 24                             dwi         64  20160124        5.0   256
# 25                           flair         52  20160124        5.0   512
# 26                             NaN        198  20160124        1.0   256
# 27                             gre         31  20160124        5.0   512
# 28                          t1post         31  20160124        5.0   512
# 29                           t1pre         13  20160124        5.0   512
# ...                            ...        ...       ...        ...   ...
# 2170                           NaN         21  20121031        5.0   256
# 2171                           NaN         16  20121031        5.0   128
# 2172                           NaN          1  20121031        5.0   256
# 2173                           NaN         16  20121031        5.0   128
# 2174                           NaN         16  20121031        5.0   128
# 2175                           NaN         16  20121031        5.0   128
# 2176                           NaN         16  20121031        5.0   128
# 2177                           NaN         16  20121031        5.0   128
# 2178                           NaN         16  20121031        5.0   128
# 2179                           dwi          1  20121031        5.0  2071
# 2180                           dwi          3  20121031        5.0   577
# 2181                           NaN         16  20121031        5.0   128
# 2182                           NaN         16  20121031        5.0   128
# 2183                         flair         21  20121031        5.0   512
# 2184               t1 pre or post?         21  20121031        5.0   512
# 2185                        t1post         21  20121031        5.0   512
# 2186                           NaN         15  20121022        8.0   256
# 2187                           NaN         17  20121019        8.0   256
# 2188                           NaN         31  20121019        5.0   256
# 2189                           NaN         62  20121019        5.0   256
# 2190                        t1post         52  20121019        3.0   512
# 2191                        t1post         88  20121022        2.0   256
# 2192                         t1pre         52  20121019        3.0   512
# 2193                        t1post         30  20121019        5.0   512
# 2194                           NaN         31  20121019        5.0   256
# 2195               t1 pre or post?         25  20121019        5.0   512
# 2196                         flair         32  20121019        5.0   512
# 2197                         flair         26  20121019        5.0   512
# 2198                            t2         46  20121019        3.0   512
# 2199  multiple modalities detected         26  20121019        5.0   256
#
#       columns                                                raw
# 0         128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 1         512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2         256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 3         256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 4         256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 5         256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 6         512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 7         512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 8         512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 9         512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 10        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 11        244  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 12        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 13        256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 14        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 15        256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 16        256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 17        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 18        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 19        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 20        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 21        128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 22        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 23        256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 24        256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 25        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 26        256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 27        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 28        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 29        512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# ...       ...                                                ...
# 2170      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2171      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2172      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2173      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2174      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2175      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2176      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2177      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2178      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2179      896  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2180     1024  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2181      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2182      128  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2183      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2184      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2185      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2186      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2187      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2188      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2189      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2190      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2191      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2192      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2193      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2194      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2195      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2196      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2197      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2198      512  /labs/gevaertlab/data/radiology/StanfordGBM/20...
# 2199      256  /labs/gevaertlab/data/radiology/StanfordGBM/20...
#
# [2200 rows x 10 columns]

# %%
dfpivot = df3.loc[:,['id', 'modality', 'nb_dicoms', 'date']]
# TODO: figure out which folder to keep in case one patient has several folders for the same view and modality
dfpivot = dfpivot.sort_values(by=['date'])
dfpivot.drop_duplicates(subset=['id', 'modality'], keep='first', inplace=True)
dfpivot = dfpivot.loc[:, ['id', 'modality', 'nb_dicoms']]
dfpivot = dfpivot.set_index(['id', 'modality'])
dfpivot = dfpivot.unstack(fill_value=0)
dfpivot = dfpivot.loc[:, 'nb_dicoms']

dfpivot
# Out:
# modality     dwi  flair  gre  multiple modalities detected  t1 pre or post?  \
# id
# Patient-01    60     52   30                             0                0
# Patient-02    64     52   31                             0                0
# Patient-03     0     24    0                            24               24
# Patient-04    62     52   32                             0                0
# Patient-05     0     36    0                            36               36
# Patient-06   176     68    0                             0               68
# Patient-07    48     49   24                             0               24
# Patient-08    26     26    0                            26                0
# Patient-09    54      0    0                            27               27
# Patient-10    80     43    0                             0               43
# Patient-100    0     26   26                             0                0
# Patient-11    60     49   30                             0                0
# Patient-13    60     51   30                             0                0
# Patient-14    60     52   30                             0                0
# Patient-15     0      0    0                             0               26
# Patient-16    56      0    0                             0               55
# Patient-17     0     26    0                             0               26
# Patient-18    60     52   30                             0                0
# Patient-19     0      0    0                             0                0
# Patient-20    56     29   29                             0                0
# Patient-21    64     32    0                             0               30
# Patient-22    60    121   30                             0                0
# Patient-24    64     25    0                            25                0
# Patient-25    46     49   23                             0               23
# Patient-26    58     27    0                            27               27
# Patient-27    64     32   32                             0                0
# Patient-28    26      0    0                             0                0
# Patient-29    26     26    0                            26                0
# Patient-30    44     22   22                             0               22
# Patient-31    62      0   25                            25                0
# ...          ...    ...  ...                           ...              ...
# Patient-66    70     41    0                            41              121
# Patient-67     0     23   23                            23                0
# Patient-68     0     24    0                             0               24
# Patient-69     0     22    0                             0               22
# Patient-70     0     22   23                             0               92
# Patient-71     0     25    0                             0               25
# Patient-72     0     24    0                             0                0
# Patient-73    60     30   30                             0                0
# Patient-74     0      0    0                            20                0
# Patient-75     0      0    0                            20                0
# Patient-76    60     30   30                             0                0
# Patient-81     0     23   23                             0                0
# Patient-82    60     30   30                             0                0
# Patient-83     0     24    0                             0               84
# Patient-84    60     30   30                             0                0
# Patient-85    25     25    0                             0               25
# Patient-86    56    121   28                             0                0
# Patient-87     0     22   22                             0              100
# Patient-88     0      0    0                             0               85
# Patient-89    60     30   30                             0                0
# Patient-90     0     24    0                             0                0
# Patient-91    60     30   30                            30                0
# Patient-92    76     28    0                             0                0
# Patient-93    64     32   32                             0               32
# Patient-94    60     30   30                             0                0
# Patient-95     0      0    0                             0                0
# Patient-96    60     30   30                            30               90
# Patient-97    60     15   30                            30                0
# Patient-98     0     21   21                             0                0
# Patient-99     0      0    0                            26                0
#
# modality     t1post  t1pre  t2
# id
# Patient-01       30     30  30
# Patient-02       31     13  32
# Patient-03       24      0  24
# Patient-04       32     32  32
# Patient-05       32     32   0
# Patient-06        0      0  68
# Patient-07       24      0  24
# Patient-08        0      0  26
# Patient-09       27      0   0
# Patient-10       43      0  43
# Patient-100      26     52  26
# Patient-11       30     30  30
# Patient-13       30     30  30
# Patient-14       30     30  30
# Patient-15       26      0  26
# Patient-16       24      0  55
# Patient-17       26      0  26
# Patient-18       30     30  30
# Patient-19       22      0  56
# Patient-20      120    120  29
# Patient-21       30      0  45
# Patient-22       30     30  30
# Patient-24        0      0  25
# Patient-25       23      0  23
# Patient-26       27      0  27
# Patient-27       32     32  32
# Patient-28       26     26  26
# Patient-29        0      0  26
# Patient-30       22      0  22
# Patient-31        0      0   0
# ...             ...    ...  ..
# Patient-66       74      0   0
# Patient-67        0      0   0
# Patient-68       24      0  24
# Patient-69       22      0  22
# Patient-70       23     23  23
# Patient-71       25      0  25
# Patient-72       34     34  29
# Patient-73       30     30  30
# Patient-74        0      0  60
# Patient-75        0      0  20
# Patient-76       30     30  30
# Patient-81       23      0  23
# Patient-82       30      0  30
# Patient-83        0      0   0
# Patient-84       30     30  30
# Patient-85       25      0  25
# Patient-86       28     28  28
# Patient-87       22     22  22
# Patient-88        0      0   0
# Patient-89       30      0  30
# Patient-90        0      0  24
# Patient-91       31     15  30
# Patient-92       28      0  28
# Patient-93       32      0  32
# Patient-94       87     30  30
# Patient-95       93      0   0
# Patient-96       30      0  30
# Patient-97       30      0  30
# Patient-98       21     21  21
# Patient-99       52     52   0
#
# [89 rows x 8 columns]

# %%
dfpivot.loc[(dfpivot.flair > 0)].shape
dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0)].shape
# df.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0) & (dfpivot.flair == dfpivot.t1post)].shape
# dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0) & (dfpivot.t1pre > 0) & (dfpivot.t2 > 0)].shape
#Counter(dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0) & (dfpivot.flair == dfpivot.t1post)].flair)
# dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0) | (dfpivot.flair > 0) & (dfpivot["t1 pre or post?"] > 0)]
# dfpivot.loc[dfpivot.flair > 0]
# Out:
# (62, 8)

# %%
# list of descriptions for which we can't classify between T1 post and T1 pre pr mutliple modalities
# df4 = df3[df3.modality == "t1 pre or post?"]
df4 = df3[df3.modality == "multiple modalities detected"]
df4.drop_duplicates(subset=['description'], keep='first', inplace=True)
df4.loc[:, ['description', 'raw']]
df4.description.tolist()
#list(np.unique(np.array(sorted(list(df3[df3.modality == "t1 pre or post?"].description)))))
# Out:
# /home/romains/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ['AX T2* GRE',
#  'Ax T2 Propeller',
#  'Ax T2* GRE',
#  'AX T1 FLAIR',
#  'AX T1 FLAIR POST',
#  'Ax T2 PROPELLER',
#  'AX T1 FLAIR GAD',
#  'AX T2 FLAIR PROPELLER',
#  'AX T2 PROPELLER',
#  'hAx T1,Flair irFSE',
#  'hAx T2* GRE F',
#  'T1 MPRAGE AXIAL 3D POST',
#  'T1 MPRAGE AXIAL 3D PRE',
#  'POST AX T1 3D MPRAGE',
#  'Ax T1 FLAIR PROP',
#  'Ax T1 FLAIR PROP POST',
#  'Ax T1 FLAIR PROP POST STEREO',
#  'Ax T1 FLAIR',
#  'T2* AX GRE']
