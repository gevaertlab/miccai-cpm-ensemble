# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

import re
import csv
import pickle

import numpy as np
import pandas as pd
from tqdm import tqdm_notebook, tqdm

import pydicom
from collections import Counter

import shutil

from utils.data_utils import arr_to_im_path
from utils.classify_utils import collect_info_patient_folder

# %% [markdown]
# ## Allow loading of radiologist annotated information

# %%
annotation_to_modality = {"T1 pre ": "t1pre",
                         "T1 pre": "t1pre",
                         "T1 post": "t1post"}

# %%
def enrich_with_dataframe_annotation(images_fields, annotation_df, verbose=False): # in-place
    unknown_modalities = set()
    for _, row in annotation_df.iterrows():
        row_descr = row.description
        if row.modality in annotation_to_modality:
            row_mod = annotation_to_modality[row.modality]
            images_fields.loc[images_fields.description == row_descr, "modality"] = row_mod
        else:
            unknown_modalities.add(row.modality)
            if verbose:
                print("Unrecognized labelled modality:", row.modality)
    print(list(unknown_modalities))

# %%
def enrich_with_radiologist_annotation(images_fields): # in-place
    def print_number_images_with_unknown_modality(images_fields):
        print("Images with unknown modality: {}".format(
            (images_fields.modality.str.contains("multiple modalities detected") | 
             images_fields.modality.str.contains("N/A") |
             images_fields.modality.str.contains("t1 pre or post?")
        ).sum()))


    annotation1 = pd.read_csv("radiologist_classification/descriptions_unclassified_t1_preVpost-annotated.csv")
    annotation2 = pd.read_csv("radiologist_classification/descriptions_unclassified_multiple_modalities-annotated.csv")
    annotation3 = pd.read_csv("radiologist_classification/descriptions_unclassified_no_modalities-annotated.csv")

    enrich_with_dataframe_annotation(images_fields, annotation1)
    print_number_images_with_unknown_modality(images_fields)

    enrich_with_dataframe_annotation(images_fields, annotation2)
    print_number_images_with_unknown_modality(images_fields)

    enrich_with_dataframe_annotation(images_fields, annotation3)
    print_number_images_with_unknown_modality(images_fields)

# %% [markdown]
# ### Load all DICOM files metadata

# %% [markdown]
# Load from csv

# %%
images_fields = pd.read_csv("images_fields.csv", na_filter=False)
# enrich_with_radiologist_annotation(images_fields)
images_fields0 = images_fields

# %%
print(len(images_fields.patient_id.unique()), 'patients')
# Out:
# 541 patients

# %%
len(images_fields)
# Out:
# 29394

# %%
images_fields.head()
# Out:
#    Unnamed: 0  columns      date              description  \
# 0           0      256  20101130              3 PLANE LOC
# 1           1      256  20101130     AXIAL SPGR-BRAIN LAB
# 2           2      256  20101130     AXIAL SPGR-BRAIN LAB
# 3           3      256  20101130  DTI 25 directions 1000b
# 4           4      512  20101130               SCREENSAVE
#
#                            full_id modality  nb_dicoms      patient_id  \
# 0  0101-01__Studies/727^1027^825^^      N/A         15  727^1027^825^^
# 1  0101-01__Studies/727^1027^825^^      N/A        124  727^1027^825^^
# 2  0101-01__Studies/727^1027^825^^      N/A        124  727^1027^825^^
# 3  0101-01__Studies/727^1027^825^^      N/A        338  727^1027^825^^
# 4  0101-01__Studies/727^1027^825^^      N/A         11  727^1027^825^^
#
#                                             raw_path  rows             study  \
# 0  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...   256  0101-01__Studies
# 1  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...   256  0101-01__Studies
# 2  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...   256  0101-01__Studies
# 3  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...   256  0101-01__Studies
# 4  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...   512  0101-01__Studies
#
#   thickness   view
# 0         5    N/A
# 1       1.6  axial
# 2       1.6  axial
# 3         5    N/A
# 4  5.000000    N/A

# %% [markdown]
# # Extracting patients for which we have full information

# %% [markdown]
# #### Looking for two modalities available at the first date

# %%
images_fields = images_fields0

# %%
indexed_images_fields = images_fields.set_index(["patient_id", "modality"]).sort_index()
indexed_images_field_notfirstdate = indexed_images_fields

# %%
print(len(indexed_images_fields.index.get_level_values(0).unique()), 'patients')
# Out:
# 541 patients

# %% [markdown]
# Keep patients with both modalities available

# %%
indexed_images_fields = indexed_images_fields.groupby("patient_id").filter(lambda x:
                                 'flair' in x.index.get_level_values(1).values)
print(len(indexed_images_fields.index.get_level_values(0).unique()), 'patients')
indexed_images_fields = indexed_images_fields.groupby("patient_id").filter(lambda x:
                                 't1post' in x.index.get_level_values(1).values)
print(len(indexed_images_fields.index.get_level_values(0).unique()), 'patients')
indexed_images_fields = indexed_images_fields.query("modality in ['t1post', 'flair']")
# Out:
# 485 patients
# 443 patients

# %% [markdown]
# Keep patients with axial view available

# %%
indexed_images_fields = indexed_images_fields.query("view == 'axial'")
print(len(indexed_images_fields.index.get_level_values(0).unique()), 'patients')
indexed_images_fields.reset_index().set_index(['patient_id', 
                                              'date', 
                                              'modality']).sort_index()
# Out:
# 426 patients
#                                     Unnamed: 0  columns  \
# patient_id     date       modality
# 101^8007^825^^ 20101227.0 flair          13033      256
#                           t1post         13028      512
# 102^9598^825^^ 20091015.0 flair            843      512
#                           t1post           844      512
#                20100203.0 flair           2406      512
#                           t1post          2407      512
# 103^7796^825^^ 20100317.0 t1post          2950      384
#                20100609.0 t1post          5742      384
# 104^601^825^^  20090926.0 flair            630      320
#                20091231.0 flair           1467      512
#                           t1post          1469      256
#                20100326.0 flair           2964      512
#                           t1post          2966      256
#                20100618.0 flair           5755      512
#                           t1post          5757      256
#                20100817.0 flair           7821      512
#                           t1post          7825      512
#                20101122.0 flair          11807      512
#                           t1post         11809      256
# 105^7017^825^^ 20090926.0 flair            634      512
#                           t1post           635      512
#                20100610.0 flair           5772      512
#                           t1post          5760      512
# 107^2217^825^^ 20090929.0 t1post           653      256
#                20100322.0 flair           2971      256
#                           t1post          2974      512
# 108^7822^825^^ 20090929.0 flair            663      512
#                20100308.0 flair           2986      512
#                           t1post          2988      512
#                20100429.0 flair           3696      512
# ...                                        ...      ...
# 977^2226^825^^ 20131120.0 flair          28222      464
#                           t1post         28226      192
#                           t1post         28227      512
# 979^8005^825^^ 20110727.0 flair          22787      512
#                           t1post         22785      512
#                20111011.0 flair          24770      256
#                           t1post         24768      512
#                20120516.0 flair          27136      512
#                           t1post         27134      512
# 99^7796^825^^  20100413.0 flair           4742      256
#                           t1post          4731      256
#                20100706.0 flair           7813      512
#                20101027.0 flair          11780      256
#                20101112.0 t1post         12996      512
#                           t1post         12997      512
#                20101122.0 flair          13013      256
#                20110209.0 flair          17005      256
#                           t1post         17003      288
#                NaN        flair          11791       -1
#                           flair          13023       -1
#                           flair          17016       -1
#                           t1post         17014       -1
# 9^7627^825^^   20090602.0 flair            210      256
#                20100421.0 flair           4752      512
#                           t1post          4753      512
#                20100811.0 flair           8822      512
#                           t1post          8823      512
#                20101020.0 flair          11797      256
#                20110112.0 flair          15791      256
#                20110321.0 flair          18755      256
#
#                                                                       description  \
# patient_id     date       modality
# 101^8007^825^^ 20101227.0 flair                                    T2 FLAIR AXIAL
#                           t1post                                          T1 AX+C
# 102^9598^825^^ 20091015.0 flair                                       +C AX FLAIR
#                           t1post                                      +c AXIAL T1
#                20100203.0 flair                                       +C AX FLAIR
#                           t1post                                      +c AXIAL T1
# 103^7796^825^^ 20100317.0 t1post                                     AX T1 IR GAD
#                20100609.0 t1post                                     AX T1 IR GAD
# 104^601^825^^  20090926.0 flair                                       T2 AX FLAIR
#                20091231.0 flair                        AX OBL FLAIR TO AC/PC LINE
#                           t1post                                   Ax OBL T1 POST
#                20100326.0 flair                        AX OBL FLAIR TO AC/PC LINE
#                           t1post                                   Ax OBL T1 POST
#                20100618.0 flair                        AX OBL FLAIR TO AC/PC LINE
#                           t1post                                   Ax OBL T1 POST
#                20100817.0 flair                                          AX FLAIR
#                           t1post                              Ax T1 FS BRAIN POST
#                20101122.0 flair                        AX OBL FLAIR TO AC/PC LINE
#                           t1post                                   Ax OBL T1 POST
# 105^7017^825^^ 20090926.0 flair                                          AX FLAIR
#                           t1post                                        AX T1 gad
#                20100610.0 flair                                  AX T2 FLAIR HEAD
#                           t1post                                    +C AX T1 HEAD
# 107^2217^825^^ 20090929.0 t1post                               ROUTINE/T1-AX-POST
#                20100322.0 flair                             ROUTINE/FLAIR-AX-POST
#                           t1post                               ROUTINE/T1-AX-POST
# 108^7822^825^^ 20090929.0 flair                                          AX FLAIR
#                20100308.0 flair                                       ax T2 FLAIR
#                           t1post                                       POST AX T1
#                20100429.0 flair                                       AX T2 FLAIR
# ...                                                                           ...
# 977^2226^825^^ 20131120.0 flair                                       flair axial
#                           t1post    t1 mpr axial mets post _only if holding still
#                           t1post                                 t1 se axial post
# 979^8005^825^^ 20110727.0 flair                                       AX T2 FLAIR
#                           t1post                                    AX SE T1 POST
#                20111011.0 flair                                       AX T2 FLAIR
#                           t1post                                    AX SE T1 POST
#                20120516.0 flair                                       Ax T2 FLAIR
#                           t1post                                         Ax T1 +c
# 99^7796^825^^  20100413.0 flair                                       AX T2 FLAIR
#                           t1post                                      AX T1 SE +C
#                20100706.0 flair                                       AX T2 FLAIR
#                20101027.0 flair                                      T2W_FLAIR AX
#                20101112.0 t1post                                         ax t1 +c
#                           t1post                            ax T1 3D 1MM fSPGR +C
#                20101122.0 flair                                      T2W_FLAIR AX
#                20110209.0 flair                                       AX T2 FLAIR
#                           t1post                                    AX T1 SE POST
#                NaN        flair                                      T2W_FLAIR AX
#                           flair                                      T2W_FLAIR AX
#                           flair                                       AX T2 FLAIR
#                           t1post                                    AX T1 SE POST
# 9^7627^825^^   20090602.0 flair                                          Ax FLAIR
#                20100421.0 flair                                       Axial FLAIR
#                           t1post                               Axial T1 FSE  Post
#                20100811.0 flair                                       Axial FLAIR
#                           t1post                               Axial T1 FSE  Post
#                20101020.0 flair                                          Ax FLAIR
#                20110112.0 flair                                          Ax FLAIR
#                20110321.0 flair                                          Ax FLAIR
#
#                                                             full_id  \
# patient_id     date       modality
# 101^8007^825^^ 20101227.0 flair     2010-12__Studies/101^8007^825^^
#                           t1post    2010-12__Studies/101^8007^825^^
# 102^9598^825^^ 20091015.0 flair     2009-10__Studies/102^9598^825^^
#                           t1post    2009-10__Studies/102^9598^825^^
#                20100203.0 flair     2010-02__Studies/102^9598^825^^
#                           t1post    2010-02__Studies/102^9598^825^^
# 103^7796^825^^ 20100317.0 t1post    2010-03__Studies/103^7796^825^^
#                20100609.0 t1post    2010-06__Studies/103^7796^825^^
# 104^601^825^^  20090926.0 flair      2009-09__Studies/104^601^825^^
#                20091231.0 flair      2009-12__Studies/104^601^825^^
#                           t1post     2009-12__Studies/104^601^825^^
#                20100326.0 flair      2010-03__Studies/104^601^825^^
#                           t1post     2010-03__Studies/104^601^825^^
#                20100618.0 flair      2010-06__Studies/104^601^825^^
#                           t1post     2010-06__Studies/104^601^825^^
#                20100817.0 flair      2010-08__Studies/104^601^825^^
#                           t1post     2010-08__Studies/104^601^825^^
#                20101122.0 flair      2010-11__Studies/104^601^825^^
#                           t1post     2010-11__Studies/104^601^825^^
# 105^7017^825^^ 20090926.0 flair     2009-09__Studies/105^7017^825^^
#                           t1post    2009-09__Studies/105^7017^825^^
#                20100610.0 flair     2010-06__Studies/105^7017^825^^
#                           t1post    2010-06__Studies/105^7017^825^^
# 107^2217^825^^ 20090929.0 t1post    2009-09__Studies/107^2217^825^^
#                20100322.0 flair     2010-03__Studies/107^2217^825^^
#                           t1post    2010-03__Studies/107^2217^825^^
# 108^7822^825^^ 20090929.0 flair     2009-09__Studies/108^7822^825^^
#                20100308.0 flair     2010-03__Studies/108^7822^825^^
#                           t1post    2010-03__Studies/108^7822^825^^
#                20100429.0 flair     2010-04__Studies/108^7822^825^^
# ...                                                             ...
# 977^2226^825^^ 20131120.0 flair     2013-11__Studies/977^2226^825^^
#                           t1post    2013-11__Studies/977^2226^825^^
#                           t1post    2013-11__Studies/977^2226^825^^
# 979^8005^825^^ 20110727.0 flair     2011-07__Studies/979^8005^825^^
#                           t1post    2011-07__Studies/979^8005^825^^
#                20111011.0 flair     2011-10__Studies/979^8005^825^^
#                           t1post    2011-10__Studies/979^8005^825^^
#                20120516.0 flair     2012-05__Studies/979^8005^825^^
#                           t1post    2012-05__Studies/979^8005^825^^
# 99^7796^825^^  20100413.0 flair      2010-04__Studies/99^7796^825^^
#                           t1post     2010-04__Studies/99^7796^825^^
#                20100706.0 flair      2010-07__Studies/99^7796^825^^
#                20101027.0 flair      2010-10__Studies/99^7796^825^^
#                20101112.0 t1post     2010-11__Studies/99^7796^825^^
#                           t1post     2010-11__Studies/99^7796^825^^
#                20101122.0 flair      2010-11__Studies/99^7796^825^^
#                20110209.0 flair      2011-02__Studies/99^7796^825^^
#                           t1post     2011-02__Studies/99^7796^825^^
#                NaN        flair      2010-10__Studies/99^7796^825^^
#                           flair      2010-11__Studies/99^7796^825^^
#                           flair      2011-02__Studies/99^7796^825^^
#                           t1post     2011-02__Studies/99^7796^825^^
# 9^7627^825^^   20090602.0 flair       2009-06__Studies/9^7627^825^^
#                20100421.0 flair       2010-04__Studies/9^7627^825^^
#                           t1post      2010-04__Studies/9^7627^825^^
#                20100811.0 flair       2010-08__Studies/9^7627^825^^
#                           t1post      2010-08__Studies/9^7627^825^^
#                20101020.0 flair       2010-10__Studies/9^7627^825^^
#                20110112.0 flair       2011-01__Studies/9^7627^825^^
#                20110321.0 flair       2011-03__Studies/9^7627^825^^
#
#                                     nb_dicoms  \
# patient_id     date       modality
# 101^8007^825^^ 20101227.0 flair            22
#                           t1post           22
# 102^9598^825^^ 20091015.0 flair            28
#                           t1post           28
#                20100203.0 flair            28
#                           t1post           28
# 103^7796^825^^ 20100317.0 t1post           26
#                20100609.0 t1post           26
# 104^601^825^^  20090926.0 flair            28
#                20091231.0 flair            26
#                           t1post           26
#                20100326.0 flair            29
#                           t1post           29
#                20100618.0 flair            26
#                           t1post           26
#                20100817.0 flair            26
#                           t1post           21
#                20101122.0 flair            26
#                           t1post           26
# 105^7017^825^^ 20090926.0 flair            30
#                           t1post           26
#                20100610.0 flair            32
#                           t1post           32
# 107^2217^825^^ 20090929.0 t1post           23
#                20100322.0 flair            21
#                           t1post           21
# 108^7822^825^^ 20090929.0 flair            36
#                20100308.0 flair            32
#                           t1post           33
#                20100429.0 flair            28
# ...                                       ...
# 977^2226^825^^ 20131120.0 flair            21
#                           t1post          160
#                           t1post           21
# 979^8005^825^^ 20110727.0 flair            28
#                           t1post           28
#                20111011.0 flair            26
#                           t1post           26
#                20120516.0 flair            28
#                           t1post           22
# 99^7796^825^^  20100413.0 flair            29
#                           t1post           29
#                20100706.0 flair            24
#                20101027.0 flair            25
#                20101112.0 t1post           60
#                           t1post          192
#                20101122.0 flair            26
#                20110209.0 flair            26
#                           t1post           26
#                NaN        flair             1
#                           flair             1
#                           flair             1
#                           t1post            1
# 9^7627^825^^   20090602.0 flair            20
#                20100421.0 flair            20
#                           t1post           20
#                20100811.0 flair            22
#                           t1post           22
#                20101020.0 flair            20
#                20110112.0 flair            20
#                20110321.0 flair            22
#
#                                                                              raw_path  \
# patient_id     date       modality
# 101^8007^825^^ 20101227.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 102^9598^825^^ 20091015.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100203.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 103^7796^825^^ 20100317.0 t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100609.0 t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 104^601^825^^  20090926.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20091231.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100326.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100618.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100817.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20101122.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 105^7017^825^^ 20090926.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100610.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 107^2217^825^^ 20090929.0 t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100322.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 108^7822^825^^ 20090929.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100308.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100429.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# ...                                                                               ...
# 977^2226^825^^ 20131120.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 979^8005^825^^ 20110727.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20111011.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20120516.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 99^7796^825^^  20100413.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100706.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20101027.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20101112.0 t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20101122.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20110209.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                NaN        flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 9^7627^825^^   20090602.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100421.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20100811.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                           t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20101020.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20110112.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                20110321.0 flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
#                                     rows             study  thickness   view
# patient_id     date       modality
# 101^8007^825^^ 20101227.0 flair      256  2010-12__Studies       5.00  axial
#                           t1post     512  2010-12__Studies       5.00  axial
# 102^9598^825^^ 20091015.0 flair      512  2009-10__Studies       5.00  axial
#                           t1post     512  2009-10__Studies       5.00  axial
#                20100203.0 flair      512  2010-02__Studies       5.00  axial
#                           t1post     512  2010-02__Studies       5.00  axial
# 103^7796^825^^ 20100317.0 t1post     384  2010-03__Studies       5.00  axial
#                20100609.0 t1post     384  2010-06__Studies       5.00  axial
# 104^601^825^^  20090926.0 flair      320  2009-09__Studies       5.00  axial
#                20091231.0 flair      512  2009-12__Studies       5.00  axial
#                           t1post     256  2009-12__Studies       5.00  axial
#                20100326.0 flair      512  2010-03__Studies       5.00  axial
#                           t1post     256  2010-03__Studies       5.00  axial
#                20100618.0 flair      512  2010-06__Studies       5.00  axial
#                           t1post     256  2010-06__Studies       5.00  axial
#                20100817.0 flair      512  2010-08__Studies       5.00  axial
#                           t1post     512  2010-08__Studies       5.00  axial
#                20101122.0 flair      512  2010-11__Studies       5.00  axial
#                           t1post     256  2010-11__Studies       5.00  axial
# 105^7017^825^^ 20090926.0 flair      512  2009-09__Studies       5.00  axial
#                           t1post     512  2009-09__Studies       5.00  axial
#                20100610.0 flair      512  2010-06__Studies       5.00  axial
#                           t1post     512  2010-06__Studies       5.00  axial
# 107^2217^825^^ 20090929.0 t1post     256  2009-09__Studies       5.00  axial
#                20100322.0 flair      256  2010-03__Studies       5.00  axial
#                           t1post     512  2010-03__Studies       5.00  axial
# 108^7822^825^^ 20090929.0 flair      512  2009-09__Studies       4.00  axial
#                20100308.0 flair      512  2010-03__Studies       4.00  axial
#                           t1post     512  2010-03__Studies       5.00  axial
#                20100429.0 flair      512  2010-04__Studies       5.00  axial
# ...                                  ...               ...        ...    ...
# 977^2226^825^^ 20131120.0 flair      512  2013-11__Studies       5.00  axial
#                           t1post     256  2013-11__Studies       1.04  axial
#                           t1post     512  2013-11__Studies       5.00  axial
# 979^8005^825^^ 20110727.0 flair      512  2011-07__Studies       5.00  axial
#                           t1post     512  2011-07__Studies       5.00  axial
#                20111011.0 flair      256  2011-10__Studies       5.00  axial
#                           t1post     512  2011-10__Studies       5.00  axial
#                20120516.0 flair      512  2012-05__Studies       5.00  axial
#                           t1post     512  2012-05__Studies       5.00  axial
# 99^7796^825^^  20100413.0 flair      256  2010-04__Studies       5.00  axial
#                           t1post     256  2010-04__Studies       5.00  axial
#                20100706.0 flair      512  2010-07__Studies       5.00  axial
#                20101027.0 flair      256  2010-10__Studies       5.00  axial
#                20101112.0 t1post     512  2010-11__Studies       3.00  axial
#                           t1post     512  2010-11__Studies       2.00  axial
#                20101122.0 flair      256  2010-11__Studies       5.00  axial
#                20110209.0 flair      256  2011-02__Studies       5.00  axial
#                           t1post     288  2011-02__Studies       5.00  axial
#                NaN        flair       -1  2010-10__Studies        NaN  axial
#                           flair       -1  2010-11__Studies        NaN  axial
#                           flair       -1  2011-02__Studies        NaN  axial
#                           t1post      -1  2011-02__Studies        NaN  axial
# 9^7627^825^^   20090602.0 flair      256  2009-06__Studies       5.00  axial
#                20100421.0 flair      512  2010-04__Studies       5.00  axial
#                           t1post     512  2010-04__Studies       5.00  axial
#                20100811.0 flair      512  2010-08__Studies       5.00  axial
#                           t1post     512  2010-08__Studies       5.00  axial
#                20101020.0 flair      256  2010-10__Studies       5.00  axial
#                20110112.0 flair      256  2011-01__Studies       5.00  axial
#                20110321.0 flair      256  2011-03__Studies       5.00  axial
#
# [3330 rows x 10 columns]

# %% [markdown]
# For two images with same view and modality, keep the most recent one.

# %%
indexed_images_fields = indexed_images_fields.sort_values(by=['date'])
indexed_images_fields = indexed_images_fields.loc[~indexed_images_fields.index.duplicated(keep='first')]

# %%
print(len(indexed_images_fields.index.get_level_values(0).unique()), 'patients')
indexed_images_fields.head()
# Out:
# 426 patients
#                          Unnamed: 0  columns        date  \
# patient_id     modality
# 125^126^825^^  t1post           119      236  20040318.0
#                flair            118      512  20040318.0
# 203^2503^825^^ flair            138      256  20090403.0
# 9^7627^825^^   flair            210      256  20090602.0
# 10^7017^825^^  t1post           147      512  20090603.0
#
#                                   description  \
# patient_id     modality
# 125^126^825^^  t1post       AXIAL T1 POST_FIL
#                flair              AXIAL FLAIR
# 203^2503^825^^ flair                 AX FLAIR
# 9^7627^825^^   flair                 Ax FLAIR
# 10^7017^825^^  t1post    AX T1 POST SPIN ECHO
#
#                                                  full_id  nb_dicoms  \
# patient_id     modality
# 125^126^825^^  t1post     2004-03__Studies/125^126^825^^         25
#                flair      2004-03__Studies/125^126^825^^         25
# 203^2503^825^^ flair     2009-04__Studies/203^2503^825^^         23
# 9^7627^825^^   flair       2009-06__Studies/9^7627^825^^         20
# 10^7017^825^^  t1post     2009-06__Studies/10^7017^825^^         76
#
#                                                                   raw_path  \
# patient_id     modality
# 125^126^825^^  t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#                flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 203^2503^825^^ flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 9^7627^825^^   flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 10^7017^825^^  t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
#                          rows             study  thickness   view
# patient_id     modality
# 125^126^825^^  t1post     320  2004-03__Studies        5.0  axial
#                flair      640  2004-03__Studies        5.0  axial
# 203^2503^825^^ flair      256  2009-04__Studies        5.0  axial
# 9^7627^825^^   flair      256  2009-06__Studies        5.0  axial
# 10^7017^825^^  t1post     512  2009-06__Studies        5.0  axial

# %% [markdown]
# Keeping patients with two modalities taken at the same date

# %%
indexed_images_fields = indexed_images_fields.groupby("patient_id").filter(lambda x: len(x) > 1 and x.date[0] == x.date[1])
print(len(indexed_images_fields.index.get_level_values(0).unique()), 'patients')
indexed_images_fields.head()
# Out:
# 255 patients
#                         Unnamed: 0  columns        date           description  \
# patient_id    modality
# 125^126^825^^ t1post           119      236  20040318.0     AXIAL T1 POST_FIL
#               flair            118      512  20040318.0           AXIAL FLAIR
# 6^2421^825^^  t1post           196      416  20090622.0  AX T1 SE FS POST 512
#               flair            197      448  20090622.0           AX T2 FLAIR
# 20^3722^825^^ t1post           173      512  20090625.0       Ax T1 FSE + GAD
#
#                                                full_id  nb_dicoms  \
# patient_id    modality
# 125^126^825^^ t1post    2004-03__Studies/125^126^825^^         25
#               flair     2004-03__Studies/125^126^825^^         25
# 6^2421^825^^  t1post     2009-06__Studies/6^2421^825^^         24
#               flair      2009-06__Studies/6^2421^825^^         24
# 20^3722^825^^ t1post    2009-06__Studies/20^3722^825^^         23
#
#                                                                  raw_path  \
# patient_id    modality
# 125^126^825^^ t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#               flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 6^2421^825^^  t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#               flair     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 20^3722^825^^ t1post    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
#                         rows             study  thickness   view
# patient_id    modality
# 125^126^825^^ t1post     320  2004-03__Studies        5.0  axial
#               flair      640  2004-03__Studies        5.0  axial
# 6^2421^825^^  t1post     512  2009-06__Studies        5.0  axial
#               flair      512  2009-06__Studies        5.0  axial
# 20^3722^825^^ t1post     512  2009-06__Studies        5.0  axial

# %%
indexed_images_fields.to_csv("rtog_kept_dicoms_T1post_flair.csv")

# %%
patients_shortlist = indexed_images_fields.index.get_level_values(0).unique().values
print(len(patients_shortlist), "patients")
patients_shortlist
# Out:
# 255 patients
# array(['125^126^825^^', '6^2421^825^^', '20^3722^825^^', '16^7758^825^^',
#        '25^7504^825^^', '27^5715^825^^', '21^3722^825^^', '46^2508^825^^',
#        '48^2503^825^^', '52^8907^825^^', '79^154^825^^', '56^2424^825^^',
#        '75^9682^825^^', '55^1324^825^^', '53^2408^825^^', '54^2421^825^^',
#        '89^3442^825^^', '85^7829^825^^', '122^9672^825^^',
#        '88^1515^825^^', '105^7017^825^^', '111^601^825^^',
#        '115^9666^825^^', '5^131^825^^', '118^2503^825^^', '119^399^825^^',
#        '141^5901^825^^', '102^9598^825^^', '23^2232^825^^',
#        '137^7774^825^^', '121^7751^825^^', '150^5901^825^^',
#        '123^7774^825^^', '129^7902^825^^', '42^9649^825^^',
#        '142^611^825^^', '160^9709^825^^', '167^8701^825^^',
#        '170^137^825^^', '138^7001^825^^', '145^2217^825^^',
#        '168^7830^825^^', '173^1324^825^^', '151^137^825^^',
#        '177^7728^825^^', '180^2503^825^^', '179^7821^825^^',
#        '193^7723^825^^', '158^7004^825^^', '226^1523^825^^',
#        '205^7627^825^^', '220^8902^825^^', '218^2519^825^^',
#        '236^7723^825^^', '248^6912^825^^', '241^1523^825^^',
#        '233^5715^825^^', '224^2123^825^^', '232^4101^825^^',
#        '245^4101^825^^', '269^2232^825^^', '228^2226^825^^',
#        '231^9733^825^^', '144^8927^825^^', '247^3474^825^^',
#        '259^7751^825^^', '275^9598^825^^', '289^2503^825^^',
#        '262^510^825^^', '293^605^825^^', '162^2503^825^^',
#        '277^9686^825^^', '299^7723^825^^', '295^2403^825^^',
#        '306^7700^825^^', '175^8201^825^^', '161^1523^825^^',
#        '308^8201^825^^', '184^1523^825^^', '333^9628^825^^',
#        '338^8907^825^^', '409^5705^825^^', '351^8201^825^^',
#        '216^7766^825^^', '355^7751^825^^', '113^9598^825^^',
#        '393^8005^825^^', '374^2508^825^^', '215^603^825^^',
#        '99^7796^825^^', '249^2503^825^^', '381^2520^825^^',
#        '230^3701^825^^', '244^2113^825^^', '61^9708^825^^',
#        '424^1201^825^^', '251^9725^825^^', '47^9598^825^^',
#        '417^7729^825^^', '394^7819^825^^', '260^2123^825^^',
#        '77^207^825^^', '273^628^825^^', '146^608^825^^', '443^511^825^^',
#        '431^7728^825^^', '149^3701^825^^', '7^7759^825^^',
#        '153^126^825^^', '444^7709^825^^', '452^2503^825^^',
#        '451^5801^825^^', '476^7848^825^^', '449^196^825^^',
#        '447^7906^825^^', '446^137^825^^', '448^3485^825^^',
#        '481^2503^825^^', '202^7751^825^^', '458^9555^825^^',
#        '457^2503^825^^', '456^399^825^^', '201^7751^825^^',
#        '477^5915^825^^', '195^9611^825^^', '335^601^825^^',
#        '221^8902^825^^', '454^1523^825^^', '466^7728^825^^',
#        '488^501^825^^', '358^3519^825^^', '503^7832^825^^',
#        '514^1202^825^^', '501^3367^825^^', '512^2245^825^^',
#        '504^8902^825^^', '532^2501^825^^', '535^9555^825^^',
#        '534^2508^825^^', '545^5670^825^^', '516^5914^825^^',
#        '550^7906^825^^', '526^7728^825^^', '559^7751^825^^',
#        '589^7751^825^^', '595^5914^825^^', '582^7644^825^^',
#        '560^1202^825^^', '580^5702^825^^', '588^7751^825^^',
#        '594^2217^825^^', '590^196^825^^', '592^508^825^^',
#        '678^3001^825^^', '610^7751^825^^', '634^8201^825^^',
#        '630^2508^825^^', '622^3701^825^^', '642^5485^825^^',
#        '631^5914^825^^', '629^2421^825^^', '644^7690^825^^',
#        '653^5901^825^^', '663^2210^825^^', '593^613^825^^',
#        '645^2520^825^^', '651^607^825^^', '326^2402^825^^',
#        '664^2232^825^^', '612^7890^825^^', '607^508^825^^',
#        '666^2421^825^^', '674^605^825^^', '694^5901^825^^',
#        '625^5901^825^^', '677^5901^825^^', '708^9705^825^^',
#        '685^399^825^^', '686^1202^825^^', '721^2440^825^^',
#        '558^131^825^^', '712^5901^825^^', '743^5914^825^^',
#        '682^8007^825^^', '204^7870^825^^', '728^2402^825^^',
#        '727^1027^825^^', '742^5901^825^^', '763^9555^825^^',
#        '739^2503^825^^', '316^7751^825^^', '744^820^825^^',
#        '755^4101^825^^', '758^1202^825^^', '726^7859^825^^',
#        '767^8005^825^^', '776^1523^825^^', '101^8007^825^^',
#        '800^207^825^^', '764^1324^825^^', '553^399^825^^',
#        '762^9598^825^^', '786^1523^825^^', '806^5901^825^^',
#        '791^2503^825^^', '640^399^825^^', '826^5901^825^^',
#        '827^7854^825^^', '784^7759^825^^', '832^4101^825^^',
#        '851^605^825^^', '813^1202^825^^', '842^603^825^^',
#        '837^3001^825^^', '853^7751^825^^', '857^8201^825^^',
#        '235^4101^825^^', '473^2111^825^^', '898^2503^825^^',
#        '274^8201^825^^', '649^1523^825^^', '878^8201^825^^',
#        '882^131^825^^', '908^7728^825^^', '896^511^825^^',
#        '900^7723^825^^', '903^1515^825^^', '506^9596^825^^',
#        '923^5914^825^^', '919^7751^825^^', '927^8201^825^^',
#        '945^207^825^^', '513^4101^825^^', '824^180^825^^',
#        '967^2508^825^^', '954^2503^825^^', '465^7728^825^^',
#        '975^601^825^^', '962^9555^825^^', '956^196^825^^',
#        '809^7751^825^^', '977^2226^825^^', '959^147^825^^',
#        '720^2411^825^^', '925^5901^825^^', '914^8201^825^^',
#        '815^1523^825^^', '804^4101^825^^', '979^8005^825^^',
#        '890^9682^825^^', '474^2421^825^^', '635^607^825^^',
#        '387^7819^825^^', '722^7504^825^^', '318^2444^825^^'], dtype=object)

# %% [markdown]
# # Investigating un-classified fields

# %%
images_fields = images_fields0

# %% [markdown]
# ### Filtering out patients for which we have full information

# %%
images_fields = images_fields.loc[~images_fields.patient_id.isin(patients_shortlist)]
print(len(images_fields.patient_id.unique()), 'patients')
# Out:
# 286 patients

# %% [markdown]
# ### Droping unwanted views

# %%
images_fields.view.unique()
# Out:
# array(['N/A', 'axial', 'coronal', 'sagital'], dtype=object)

# %%
# drop any row for which view is known not to be axial.
images_fields = images_fields.query("view not in ('sagital', 'coronal')")

# %%
print(len(images_fields.patient_id.unique()), 'patients')
# Out:
# 285 patients

# %%
len(images_fields)
# Out:
# 11251

# %% [markdown]
# ### Droping unwanted modalities

# %%
images_fields.modality.unique()
# Out:
# array(['N/A', 't2', 'flair', 't1pre', 't1post', 't1 pre or post?',
#        'multiple modalities detected: t2/gre', 'gre', 'dwi',
#        'multiple modalities detected: t2/blade',
#        'multiple modalities detected: dwi/propeller',
#        'multiple modalities detected: t2/flair/propeller',
#        'multiple modalities detected: t2/propeller',
#        'multiple modalities detected: t1/mprage',
#        'multiple modalities detected: t1/flair', 'mprage',
#        'multiple modalities detected: t1/blade',
#        'multiple modalities detected: flair/blade',
#        'multiple modalities detected: t1/gre',
#        'multiple modalities detected: t1/t2', 'blade',
#        'multiple modalities detected: t1/flair/propeller',
#        'multiple modalities detected: t2/mprage'], dtype=object)

# %%
# drop any row for which modality is known not to be in (T1post, FLAIR).
images_fields = images_fields.query("modality not in ('t1pre', 't2')")

# %%
print(len(images_fields.patient_id.unique()), 'patients')
# Out:
# 284 patients

# %%
len(images_fields)
# Out:
# 9917

# %% [markdown]
# ### Unclassified modality cases

# %% [markdown]
# ##### T1post vs. T1pre

# %% [markdown]
# List of descriptions for which we can't classify between T1 post and T1 pre

# %%
pre_or_post_images_fields = images_fields[images_fields.modality == "t1 pre or post?"]
print(len(pre_or_post_images_fields.description.unique()))
print(len(pre_or_post_images_fields))
sorted(list(pre_or_post_images_fields.description.unique()))
# Out:
# 213
# 1030
# ['* Brain    *AX T1/SE',
#  '*T1 AXIAL INC NOSE/FACE/TOP HEAD',
#  '+AX T1',
#  '+AX T1 FSE',
#  '+AX T1 SE',
#  '+Ax T1',
#  '+Ax T1 SE',
#  '1. AX SE T1',
#  '1. AX TSE T1',
#  '1MM AX SPGR 3D T1+16C',
#  '2. AX SE T1 FS W',
#  '2. AX SE T1 FS W  10 ML GADAVIST',
#  '2. AX SE T1 FS W  15ML MAGNEVIST',
#  '2. AX SE T1 W FS',
#  '2. AX TSE T1 FS W  10ML GADAVIST',
#  '2. AX TSE T1 FS W  12ML GADAVIST',
#  '2. AX TSE T1 FS W  20ML MAGNEVIST',
#  '2. AX TSE T1 FS W 20 ML MAGNEVIST',
#  '3d T1 FSPGR (INCLUDE NOSE TIP',
#  '7 -Ax T1',
#  '7-Ax T1',
#  'AX 2D T1',
#  'AX 3D FSPGR T1 BRAINLAB',
#  'AX 3D T1',
#  'AX 3D T1 / Corrected rCBV',
#  'AX 3D T1 / Leakage',
#  'AX FSE T1',
#  'AX FSPGR 3D T1 +16mL',
#  'AX FSPGR 3D T1 +17mL',
#  'AX FSPGR 3D T1 +20mL',
#  'AX SE T1',
#  'AX SE T1 512',
#  'AX SPGR T1',
#  'AX SPGR T1_ND',
#  'AX T1',
#  'AX T1 3D FLASH  THIN 1.0MM',
#  'AX T1 3D FLASH THIN 1.0 MM',
#  'AX T1 3D FSPGR +17mL',
#  'AX T1 BRAIN',
#  'AX T1 C+magnevist',
#  'AX T1 FC PG MTC',
#  'AX T1 FLASH',
#  'AX T1 FLASH 2D',
#  'AX T1 FSPGR',
#  'AX T1 FSPGR 3D',
#  'AX T1 IR',
#  'AX T1 MPR',
#  'AX T1 PG W/MTC',
#  'AX T1 SE',
#  'AX T1 SE 512',
#  'AX T1 SE parallel to ac-pc',
#  'AX T1 THIN FOR RAD TX',
#  'AX T1 TIRM DARK FLUID',
#  'AX T1 TSE',
#  'AX T1 mapping',
#  'AX T1 w/fc',
#  'AX T1-OPT',
#  'AX T1W_SE',
#  'AX t1 CLEAR',
#  'AXCT1SE',
#  'AXI T1 SPGR STEALTH',
#  'AXIAL T1',
#  'AXIAL T1 SE',
#  'AXL T1',
#  'AXL T1 FSE',
#  'AX_T1',
#  'Ax 3D SPGR T1',
#  'Ax 3D SPGR T1 - Standard',
#  'Ax 3mm T1 3D',
#  'Ax 3mmT1 3dspgr',
#  'Ax OBL T1 TO AC/PC LINE',
#  'Ax SE T1',
#  'Ax T1',
#  'Ax T1 3d 3mm SPGR',
#  'Ax T1 FSE',
#  'Ax T1 FSPGR 3D*',
#  'Ax T1 MATCH PERFUSION',
#  'Ax T1 MP SPGR',
#  'Ax T1 MP SPGR 3:20',
#  'Ax T1 PG FS',
#  'Ax T1 SE',
#  'Ax T1 SE F',
#  'Ax T1 SE PostC',
#  'Ax T1 TSE',
#  'Ax T13d SPGR 3mm',
#  'Ax T13mm 3dspgr',
#  'AxT1',
#  'AxT1( 256Sq.No angle)',
#  'AxT1(256Sq.No angle)',
#  'Axial 3D T1',
#  'Axial T1',
#  'Axial T1 FSE',
#  'Axial T1 reformat',
#  'BRAIN_ROUTINE/T1_TRA',
#  'BRIAN AX T1 SRS',
#  'BRN AX T1',
#  'Brain      T1 AX#',
#  'CorT1(256Sq.No angle.Tumor only)',
#  'FL02C/Ax T1',
#  'H2:AX T1 IR',
#  'MT T1 SE FS TRA_C',
#  'O-Ax T1 FSE F',
#  'POSTAX T1 BRAINLAB',
#  'PosDisp: [10] se t1 axial',
#  'PosDisp: [11] t1_mpr_axial  2mmGAD',
#  'PosDisp: [6] T1 SAGITTAL',
#  'ROUTINE/T1-AX',
#  'RTN/AX-T1',
#  'RTN/AX-T1_PG-FC-MTC',
#  'SAGITTAL T1',
#  'SAGT1(256Sq.No angle)',
#  'SE_t1 ax',
#  'STEALTH/AX-T1-MPR',
#  'STEALTH_BJC/3D_T1_TRA_2MM_',
#  'SagT1',
#  'Sagittal T1',
#  'T1 AX',
#  'T1 AX  FC',
#  'T1 AX  SE',
#  'T1 AX SE',
#  'T1 AXIAL',
#  'T1 Axials',
#  'T1 BRAINLAB',
#  'T1 FL AXIAL',
#  'T1 MAP FA 2',
#  'T1 MAP FA10',
#  'T1 MAP FA5',
#  'T1 MP RAGE AXIAL 2MM',
#  'T1 MTC',
#  'T1 Recon Position<MPR Collection>',
#  'T1 SAGITTAL',
#  'T1 SE AX',
#  'T1 SE Axial',
#  'T1 SE FS TRA_C',
#  'T1 SE TRA',
#  'T1 SE TRS',
#  'T1 TRA_FIL',
#  'T1AXBRAINLAB',
#  'T1Map_10',
#  'T1Map_15',
#  'T1Map_2',
#  'T1Map_20',
#  'T1W AXIAL',
#  'T1W _ SE',
#  'T1W/3D/TFE',
#  'T1W_3D_ISONAV',
#  'T1W_3D_STRYKER',
#  'T1W_3D_TFE',
#  'T1W_3D_stryker',
#  'T1W_IR_TSE',
#  'T1W_SE',
#  'T1W_SE AX',
#  'T1_3D  OTS',
#  'T1_SE_AX',
#  'T1_SE_AX_FIL_1',
#  'T1_SE_AX_FLOWCOMP_FIL_1',
#  'T1w Axial mpr',
#  'T1w Axial mpr_postGADO',
#  'TIR T1 AX',
#  'TRA T1 SE',
#  'TRA T1FS TSE MSMA',
#  'TRA TSE T1 FS--CSP--',
#  'TRAN FL2D T1 LOC',
#  'TRAN SE T1',
#  'TRANS 3D T1 FLASH 1X1X2',
#  'TRANS 3D T1 FLASH STEALTH',
#  'Tumor_Metastasis_BJC/T1FS_',
#  'Tumor_Metastasis_BJC/T1_CO',
#  'Tumor_Metastasis_BJC/T1_TR',
#  'XL Axial T1 FS c+E',
#  'ax T1 3D SENSE',
#  'ax t1 mpr PG STEALTH',
#  'axial_t1_1mm_isotropic',
#  'eT1 AX',
#  'mtt1',
#  'se t1 axial',
#  't1 corpost fs',
#  't1 se  tra  flow comp_FIL_1',
#  't1 se ax',
#  't1 tra',
#  't1_AX',
#  't1_ax_flow comp',
#  't1_ax_se_FIL',
#  't1_fl2d_tra',
#  't1_fl3d_ax',
#  't1_mpr_1mm_p2_pos50',
#  't1_mpr_axial  2mmGAD',
#  't1_mpr_ns_axial',
#  't1_mpr_ns_axial_p2_iso_apps 5_12_09',
#  't1_mpr_tra',
#  't1_mpr_tra_iso',
#  't1_mpr_tra_iso_contrast',
#  't1_mpr_tra_p2_ mets PG 1.1',
#  't1_mpr_tra_p2_iso',
#  't1_mpr_tra_p2_iso / rCBV',
#  't1_mpr_tra_test_FIL',
#  't1_se_AXIAL',
#  't1_se_ax',
#  't1_se_axial',
#  't1_se_axial PG',
#  't1_se_r_ax',
#  't1_se_r_tra',
#  't1_se_tra',
#  't1_se_tra_320',
#  't1_se_tra_320_FIL',
#  't1_se_tra_FIL',
#  't1_se_tra_FIL_1',
#  't1_se_tra_brain_lab',
#  't1_se_tra_fc',
#  't1_se_trans',
#  't1_se_trans_meta_scan',
#  't1_tfl_tra',
#  't1_tse_r_tra_p2']

# %% [markdown]
# Description for which we can't classify between T1 post and T1 pre; and related DICOM folder paths.

# %%
pre_or_post_images_fields = pre_or_post_images_fields.loc[:, ["patient_id", "description", "raw_path"]].sort_values("description").reset_index(drop=True)
pre_or_post_images_fields
# Out:
#           patient_id                       description  \
# 0      84^7504^825^^              * Brain    *AX T1/SE
# 1     339^9598^825^^  *T1 AXIAL INC NOSE/FACE/TOP HEAD
# 2     373^9598^825^^  *T1 AXIAL INC NOSE/FACE/TOP HEAD
# 3     654^9598^825^^  *T1 AXIAL INC NOSE/FACE/TOP HEAD
# 4     332^7729^825^^                            +AX T1
# 5     541^7729^825^^                            +AX T1
# 6     332^7729^825^^                            +AX T1
# 7     332^7729^825^^                        +AX T1 FSE
# 8     541^7729^825^^                        +AX T1 FSE
# 9     199^7729^825^^                        +AX T1 FSE
# 10    961^7729^825^^                         +AX T1 SE
# 11    961^7729^825^^                         +AX T1 SE
# 12    817^7729^825^^                         +AX T1 SE
# 13    961^7729^825^^                         +AX T1 SE
# 14    668^7627^825^^                            +Ax T1
# 15      9^7627^825^^                            +Ax T1
# 16    483^7627^825^^                            +Ax T1
# 17    668^7627^825^^                            +Ax T1
# 18      9^7627^825^^                            +Ax T1
# 19      9^7627^825^^                            +Ax T1
# 20    668^7627^825^^                            +Ax T1
# 21    668^7627^825^^                            +Ax T1
# 22    483^7627^825^^                            +Ax T1
# 23      9^7627^825^^                            +Ax T1
# 24    483^7627^825^^                            +Ax T1
# 25    483^7627^825^^                            +Ax T1
# 26    668^7627^825^^                            +Ax T1
# 27    668^7627^825^^                            +Ax T1
# 28    332^7729^825^^                         +Ax T1 SE
# 29    817^7729^825^^                         +Ax T1 SE
# ...              ...                               ...
# 1000  759^2105^825^^                         t1_se_tra
# 1001  491^7877^825^^                         t1_se_tra
# 1002  759^2105^825^^                         t1_se_tra
# 1003  759^2105^825^^                         t1_se_tra
# 1004  418^2514^825^^                         t1_se_tra
# 1005  718^7859^825^^                         t1_se_tra
# 1006  922^2101^825^^                         t1_se_tra
# 1007  673^2514^825^^                     t1_se_tra_320
# 1008  266^2514^825^^                     t1_se_tra_320
# 1009  673^2514^825^^                     t1_se_tra_320
# 1010  673^2514^825^^                     t1_se_tra_320
# 1011  266^2514^825^^                     t1_se_tra_320
# 1012  266^2514^825^^                     t1_se_tra_320
# 1013  418^2514^825^^                     t1_se_tra_320
# 1014  673^2514^825^^                     t1_se_tra_320
# 1015  418^2514^825^^                 t1_se_tra_320_FIL
# 1016  266^2514^825^^                 t1_se_tra_320_FIL
# 1017  266^2514^825^^                     t1_se_tra_FIL
# 1018  836^3459^825^^                   t1_se_tra_FIL_1
# 1019  836^3459^825^^                   t1_se_tra_FIL_1
# 1020  836^3459^825^^                   t1_se_tra_FIL_1
# 1021  836^3459^825^^                   t1_se_tra_FIL_1
# 1022  453^2443^825^^               t1_se_tra_brain_lab
# 1023  583^9519^825^^                      t1_se_tra_fc
# 1024  920^3521^825^^                       t1_se_trans
# 1025  920^3521^825^^                       t1_se_trans
# 1026  920^3521^825^^             t1_se_trans_meta_scan
# 1027  759^2105^825^^                        t1_tfl_tra
# 1028  759^2105^825^^                        t1_tfl_tra
# 1029  820^7906^825^^                   t1_tse_r_tra_p2
#
#                                                raw_path
# 0     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 2     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 3     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 4     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 6     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 7     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 8     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 9     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 10    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 11    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 12    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 13    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 14    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 15    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 16    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 17    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 18    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 19    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 20    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 21    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 22    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 23    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 24    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 25    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 26    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 27    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 28    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 29    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# ...                                                 ...
# 1000  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1001  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1002  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1003  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1004  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1005  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1006  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1007  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1008  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1009  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1010  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1011  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1012  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1013  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1014  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1015  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1016  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1017  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1018  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1019  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1020  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1021  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1022  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1023  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1024  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1025  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1026  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1027  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1028  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1029  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
# [1030 rows x 3 columns]

# %%
pre_or_post_images_fields.to_csv("images_unclassified_t1_preVpost.csv")

# %%
pre_or_post_descriptions = pre_or_post_images_fields.drop_duplicates("description").reset_index(drop=True)
pre_or_post_descriptions
# Out:
#          patient_id                          description  \
# 0     84^7504^825^^                 * Brain    *AX T1/SE
# 1    339^9598^825^^     *T1 AXIAL INC NOSE/FACE/TOP HEAD
# 2    332^7729^825^^                               +AX T1
# 3    332^7729^825^^                           +AX T1 FSE
# 4    961^7729^825^^                            +AX T1 SE
# 5    668^7627^825^^                               +Ax T1
# 6    332^7729^825^^                            +Ax T1 SE
# 7    520^3343^825^^                          1. AX SE T1
# 8    787^3343^825^^                         1. AX TSE T1
# 9    411^7735^825^^                1MM AX SPGR 3D T1+16C
# 10   778^3343^825^^                     2. AX SE T1 FS W
# 11   787^3343^825^^     2. AX SE T1 FS W  10 ML GADAVIST
# 12   586^3343^825^^     2. AX SE T1 FS W  15ML MAGNEVIST
# 13   520^3343^825^^                     2. AX SE T1 W FS
# 14   787^3343^825^^     2. AX TSE T1 FS W  10ML GADAVIST
# 15   787^3343^825^^     2. AX TSE T1 FS W  12ML GADAVIST
# 16   787^3343^825^^    2. AX TSE T1 FS W  20ML MAGNEVIST
# 17   787^3343^825^^    2. AX TSE T1 FS W 20 ML MAGNEVIST
# 18    427^399^825^^        3d T1 FSPGR (INCLUDE NOSE TIP
# 19   208^1201^825^^                             7 -Ax T1
# 20   208^1201^825^^                              7-Ax T1
# 21   624^5915^825^^                             AX 2D T1
# 22   405^9699^825^^              AX 3D FSPGR T1 BRAINLAB
# 23   471^2131^825^^                             AX 3D T1
# 24   471^2131^825^^            AX 3D T1 / Corrected rCBV
# 25   471^2131^825^^                   AX 3D T1 / Leakage
# 26   611^7890^825^^                            AX FSE T1
# 27   396^7735^825^^                 AX FSPGR 3D T1 +16mL
# 28   396^7735^825^^                 AX FSPGR 3D T1 +17mL
# 29   312^7735^825^^                 AX FSPGR 3D T1 +20mL
# ..              ...                                  ...
# 183  751^6401^825^^                          t1_fl2d_tra
# 184   68^6001^825^^                           t1_fl3d_ax
# 185  156^2101^825^^                  t1_mpr_1mm_p2_pos50
# 186  114^7720^825^^                 t1_mpr_axial  2mmGAD
# 187  130^1518^825^^                      t1_mpr_ns_axial
# 188  899^3495^825^^  t1_mpr_ns_axial_p2_iso_apps 5_12_09
# 189   29^9521^825^^                           t1_mpr_tra
# 190  453^2443^825^^                       t1_mpr_tra_iso
# 191   714^607^825^^              t1_mpr_tra_iso_contrast
# 192  116^2226^825^^           t1_mpr_tra_p2_ mets PG 1.1
# 193  222^7859^825^^                    t1_mpr_tra_p2_iso
# 194   62^7015^825^^             t1_mpr_tra_p2_iso / rCBV
# 195  673^2514^825^^                  t1_mpr_tra_test_FIL
# 196  491^7877^825^^                          t1_se_AXIAL
# 197  423^7758^825^^                             t1_se_ax
# 198  116^2226^825^^                          t1_se_axial
# 199  116^2226^825^^                       t1_se_axial PG
# 200  345^6001^825^^                           t1_se_r_ax
# 201  718^7859^825^^                          t1_se_r_tra
# 202   62^7015^825^^                            t1_se_tra
# 203  673^2514^825^^                        t1_se_tra_320
# 204  418^2514^825^^                    t1_se_tra_320_FIL
# 205  266^2514^825^^                        t1_se_tra_FIL
# 206  836^3459^825^^                      t1_se_tra_FIL_1
# 207  453^2443^825^^                  t1_se_tra_brain_lab
# 208  583^9519^825^^                         t1_se_tra_fc
# 209  920^3521^825^^                          t1_se_trans
# 210  920^3521^825^^                t1_se_trans_meta_scan
# 211  759^2105^825^^                           t1_tfl_tra
# 212  820^7906^825^^                      t1_tse_r_tra_p2
#
#                                               raw_path
# 0    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 2    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 3    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 4    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 6    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 7    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 8    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 9    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 10   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 11   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 12   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 13   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 14   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 15   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 16   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 17   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 18   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 19   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 20   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 21   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 22   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 23   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 24   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 25   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 26   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 27   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 28   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 29   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# ..                                                 ...
# 183  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 184  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 185  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 186  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 187  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 188  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 189  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 190  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 191  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 192  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 193  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 194  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 195  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 196  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 197  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 198  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 199  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 200  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 201  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 202  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 203  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 204  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 205  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 206  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 207  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 208  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 209  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 210  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 211  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 212  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
# [213 rows x 3 columns]

# %%
pre_or_post_descriptions.to_csv("descriptions_unclassified_t1_preVpost.csv")

# %% [markdown]
# ##### Multiple modalities detected

# %% [markdown]
# List of descriptions for which we can't classify modality with multiple modalities

# %%
multiple_mod_images_fields = images_fields[['multiple modalities detected' in s for s in images_fields.modality]]
print(len(multiple_mod_images_fields.description.unique()))
print(len(multiple_mod_images_fields))
sorted(list(multiple_mod_images_fields.description.unique()))
# Out:
# 138
# 624
# ['*AX GRE T2*',
#  '*head3-pl T2* FGRE S',
#  '+Ax T2 FLAIR PROPELLER',
#  '+Ax T2 PROPELLER',
#  '+Ax T2 Propeller',
#  '+Ax T2Flair Propeller',
#  '+C AX T1 MPRAGE',
#  '+C Ax T2* GRE',
#  '+C T1Flair Propeller',
#  '+T2 Propeller',
#  '1-3-pl T2* FGRE',
#  '3 pl T2* FGRE S',
#  '3-D T2* GRE EPI SENSE',
#  '3-pl T2* FGRE',
#  '3-pl T2* FGRE S',
#  '3-pl T2* FGRE S HEAD  PRE',
#  '3D T2 FGRE +C STEALTH',
#  'AX 3D T1  MPRAGE sp GAD',
#  'AX 3D T1 MPRAGE',
#  'AX FLAIR BLADE',
#  'AX FLAIR BLADE FATSAT',
#  'AX FSE T2 Propeller',
#  'AX GRE T2',
#  'AX GRE T2*',
#  'AX GRE T2* (Melanoma, Bleed)',
#  'AX GRE T2* EPI',
#  'AX IR T2 BLADE',
#  'AX T1 FLAIR',
#  'AX T1 FLAIR (angled) + C',
#  'AX T1 FLAIR +C',
#  'AX T1 FLAIR FS POST',
#  'AX T1 FLAIR POST FS',
#  'AX T1 FLAIR PRE',
#  'AX T1 FLAIR PRE GAD',
#  'AX T1 FLAIR c+',
#  'AX T1 MPRAGE',
#  'AX T1 MPRAGE POST-iso voxel',
#  'AX T1 MPRAGE PRE-iso voxel',
#  'AX T1 POST FS BLADE',
#  'AX T2 BLADE',
#  'AX T2 FLAIR propeller',
#  'AX T2 GRE',
#  'AX T2 GRE HEMO',
#  'AX T2 GRE RPT',
#  'AX T2 GRE_FIL',
#  'AX T2 GRE_HEME TE30',
#  'AX T2 PROPELLER',
#  'AX T2 Propeller',
#  'AX T2 Propeller fat',
#  'AX T2 propeller',
#  'AX T2* GRE',
#  'AX T2* gre',
#  'AXI T2 GRE STEALTH',
#  'AXIAL FLAIR BLADE',
#  'AXIAL T1 MPRAGE POST',
#  'Ax GRE T2* (Melanoma/Bleed)',
#  'Ax T1 (FLAIR)',
#  'Ax T1 FLAIR',
#  'Ax T1 FLAIR C+',
#  'Ax T1 FLAIR FS POST',
#  'Ax T1 FLAIR POST',
#  'Ax T1 FLAIR Post',
#  'Ax T1 Flair +C',
#  'Ax T1 Flair pre',
#  'Ax T2  FS Propeller',
#  'Ax T2 FLAIR PROPELLER',
#  'Ax T2 FSE/Propeller',
#  'Ax T2 PROPELLER',
#  'Ax T2 PROPELLER POST',
#  'Ax T2 Propeller',
#  'Ax T2* GRE',
#  'Ax T2* GRE F',
#  'Ax T2* GRE HEMO SEQ',
#  'Ax T2* GRE PRE',
#  'Ax T2* GRE S',
#  'Ax T2*mpgre',
#  'Ax T2Flair Propeller',
#  'BLADE FLAIR FS AXIAL',
#  'BRN AX T2 GRE',
#  'DWI Propeller',
#  'FLAIR  AXIAL BLADE',
#  'FLAIR BLADE',
#  'FLAIR_blade_tra_dark-fl',
#  'Intra op POST first rescetion SURGERY AX T1 MPRAGE +GAD',
#  'Intra op POST first rescetion SURGERY AX T1 MPRAGE +GAD_SUB',
#  'Intra op Post first resection AX T1 MPRAGE -GAD',
#  'MPRAGE ADNI iPAT2',
#  'POST Ax T1 FLAIR',
#  'PROPELLER DWI M4',
#  'PROPELLER T2',
#  'Propeller T2Flair',
#  'T1  AXIAL BLADE',
#  'T1  AXIAL BLADE POST',
#  'T1 AX FLAIR',
#  'T1 AX MPRAGE C+',
#  'T1 FLAIR AX',
#  'T1 FLAIR AX GAD',
#  'T1 FLAIR AXL',
#  'T1 FLAIR AXL POST',
#  'T1 GRE AXIAL',
#  'T1 MPRAGE AXIAL POST',
#  'T1 MPRAGE ISOTROPIC POST',
#  'T1+C MPRAGE 3D',
#  'T1Flair Propeller',
#  'T1W FLAIR AX',
#  'T1_3D_MPRAGE_AX_FIL_1',
#  'T1_MPRAGE_AX',
#  'T1_MPRAGE_FSPGR_AX3D',
#  'T2 AXIAL BLADE',
#  'T2 BLADE',
#  'T2 FLAIR PROPELLER',
#  'T2 GRE AX',
#  'T2 Propeller',
#  'T2* GRE EPI SENSE',
#  'T2* GRE epi AX SENSE',
#  'T2W_FFE GRE HEMO',
#  'T2_AX_BLADE',
#  'TRA BLADE T2',
#  'TRA FLAIR BLADE',
#  'TRA T1 BLADE',
#  'TRA T2 BLADE',
#  'TRAN 3D T1 GRE 2.5MM',
#  'TRAN 3D T1 GRE 2.5MM++NO ANGLE++',
#  'TRAN 3D T1 GRE 2MM',
#  'ax flair blade -motion',
#  'ax t2 fs blade-motion',
#  'eBRN AX T2 GRE',
#  'eT1 FLAIR AX SENSE',
#  'head3-pl T2* FGRE S',
#  't1 axial BLADE',
#  't1_blade_tra_dark-fl',
#  't1_blade_tra_fs post',
#  't1_mpr_tra_pat2_iso',
#  't1_mpr_tra_pat2_iso_FIL',
#  't2_blade_fs_tra',
#  't2_blade_tra_320',
#  't2_blade_tra_dark-fl',
#  't2_blade_tra_dark-fl_4mm']

# %% [markdown]
# Description for which we can't classify between T1 post and T1 pre; and related DICOM folder paths.

# %%
multiple_mod_images_fields = multiple_mod_images_fields.loc[:, ["patient_id", "description", "raw_path"]].sort_values("description").reset_index(drop=True)
multiple_mod_images_fields
# Out:
#          patient_id               description  \
# 0    376^5915^825^^               *AX GRE T2*
# 1    339^9598^825^^      *head3-pl T2* FGRE S
# 2    373^9598^825^^      *head3-pl T2* FGRE S
# 3    654^9598^825^^      *head3-pl T2* FGRE S
# 4    817^7729^825^^    +Ax T2 FLAIR PROPELLER
# 5    961^7729^825^^    +Ax T2 FLAIR PROPELLER
# 6    961^7729^825^^    +Ax T2 FLAIR PROPELLER
# 7    961^7729^825^^          +Ax T2 PROPELLER
# 8    961^7729^825^^          +Ax T2 PROPELLER
# 9    817^7729^825^^          +Ax T2 PROPELLER
# 10   199^7729^825^^          +Ax T2 Propeller
# 11   199^7729^825^^          +Ax T2 Propeller
# 12   332^7729^825^^          +Ax T2 Propeller
# 13   199^7729^825^^     +Ax T2Flair Propeller
# 14   332^7729^825^^     +Ax T2Flair Propeller
# 15   199^7729^825^^     +Ax T2Flair Propeller
# 16   344^7766^825^^           +C AX T1 MPRAGE
# 17   881^3431^825^^             +C Ax T2* GRE
# 18   422^2503^825^^      +C T1Flair Propeller
# 19   421^2503^825^^      +C T1Flair Propeller
# 20   561^2503^825^^      +C T1Flair Propeller
# 21   348^2503^825^^      +C T1Flair Propeller
# 22   422^2503^825^^      +C T1Flair Propeller
# 23   440^2503^825^^      +C T1Flair Propeller
# 24   422^2503^825^^      +C T1Flair Propeller
# 25   421^2503^825^^      +C T1Flair Propeller
# 26   421^2503^825^^      +C T1Flair Propeller
# 27   421^2503^825^^      +C T1Flair Propeller
# 28   422^2503^825^^      +C T1Flair Propeller
# 29   332^7729^825^^             +T2 Propeller
# ..              ...                       ...
# 594  654^9598^825^^       head3-pl T2* FGRE S
# 595  654^9598^825^^       head3-pl T2* FGRE S
# 596  339^9598^825^^       head3-pl T2* FGRE S
# 597  654^9598^825^^       head3-pl T2* FGRE S
# 598  222^7859^825^^            t1 axial BLADE
# 599  222^7859^825^^            t1 axial BLADE
# 600  899^3495^825^^      t1_blade_tra_dark-fl
# 601  899^3495^825^^      t1_blade_tra_dark-fl
# 602  899^3495^825^^      t1_blade_tra_fs post
# 603  899^3495^825^^      t1_blade_tra_fs post
# 604  673^2514^825^^       t1_mpr_tra_pat2_iso
# 605  673^2514^825^^       t1_mpr_tra_pat2_iso
# 606  673^2514^825^^       t1_mpr_tra_pat2_iso
# 607  673^2514^825^^       t1_mpr_tra_pat2_iso
# 608  266^2514^825^^   t1_mpr_tra_pat2_iso_FIL
# 609  266^2514^825^^   t1_mpr_tra_pat2_iso_FIL
# 610  266^2514^825^^   t1_mpr_tra_pat2_iso_FIL
# 611  899^3495^825^^           t2_blade_fs_tra
# 612  899^3495^825^^           t2_blade_fs_tra
# 613  490^2408^825^^          t2_blade_tra_320
# 614   66^2408^825^^          t2_blade_tra_320
# 615  922^2101^825^^          t2_blade_tra_320
# 616  922^2101^825^^          t2_blade_tra_320
# 617  222^7859^825^^          t2_blade_tra_320
# 618  899^3495^825^^      t2_blade_tra_dark-fl
# 619   66^2408^825^^      t2_blade_tra_dark-fl
# 620  222^7859^825^^      t2_blade_tra_dark-fl
# 621  899^3495^825^^      t2_blade_tra_dark-fl
# 622  490^2408^825^^      t2_blade_tra_dark-fl
# 623  751^6401^825^^  t2_blade_tra_dark-fl_4mm
#
#                                               raw_path
# 0    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 2    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 3    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 4    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 6    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 7    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 8    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 9    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 10   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 11   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 12   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 13   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 14   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 15   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 16   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 17   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 18   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 19   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 20   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 21   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 22   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 23   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 24   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 25   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 26   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 27   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 28   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 29   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# ..                                                 ...
# 594  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 595  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 596  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 597  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 598  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 599  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 600  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 601  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 602  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 603  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 604  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 605  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 606  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 607  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 608  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 609  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 610  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 611  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 612  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 613  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 614  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 615  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 616  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 617  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 618  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 619  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 620  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 621  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 622  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 623  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
# [624 rows x 3 columns]

# %%
multiple_mod_images_fields.to_csv("images_unclassified_multiple_modalities.csv")

# %%
multiple_mod_descriptions = multiple_mod_images_fields.drop_duplicates("description").reset_index(drop=True)
multiple_mod_descriptions
# Out:
#          patient_id                       description  \
# 0    376^5915^825^^                       *AX GRE T2*
# 1    339^9598^825^^              *head3-pl T2* FGRE S
# 2    817^7729^825^^            +Ax T2 FLAIR PROPELLER
# 3    961^7729^825^^                  +Ax T2 PROPELLER
# 4    199^7729^825^^                  +Ax T2 Propeller
# 5    199^7729^825^^             +Ax T2Flair Propeller
# 6    344^7766^825^^                   +C AX T1 MPRAGE
# 7    881^3431^825^^                     +C Ax T2* GRE
# 8    422^2503^825^^              +C T1Flair Propeller
# 9    332^7729^825^^                     +T2 Propeller
# 10   892^1201^825^^                   1-3-pl T2* FGRE
# 11   421^2503^825^^                   3 pl T2* FGRE S
# 12    19^8007^825^^             3-D T2* GRE EPI SENSE
# 13   498^7751^825^^                     3-pl T2* FGRE
# 14   331^2503^825^^                   3-pl T2* FGRE S
# 15    10^7017^825^^         3-pl T2* FGRE S HEAD  PRE
# 16   396^7735^825^^             3D T2 FGRE +C STEALTH
# 17   523^5702^825^^           AX 3D T1  MPRAGE sp GAD
# 18   757^3526^825^^                   AX 3D T1 MPRAGE
# 19   648^5712^825^^                    AX FLAIR BLADE
# 20   497^7877^825^^             AX FLAIR BLADE FATSAT
# 21    267^605^825^^               AX FSE T2 Propeller
# 22   684^2116^825^^                         AX GRE T2
# 23   376^5915^825^^                        AX GRE T2*
# 24   396^7735^825^^      AX GRE T2* (Melanoma, Bleed)
# 25   304^7823^825^^                    AX GRE T2* EPI
# 26    90^9521^825^^                    AX IR T2 BLADE
# 27   909^1514^825^^                       AX T1 FLAIR
# 28    412^501^825^^          AX T1 FLAIR (angled) + C
# 29   855^7915^825^^                    AX T1 FLAIR +C
# ..              ...                               ...
# 108   768^131^825^^                    T2 AXIAL BLADE
# 109  752^9521^825^^                          T2 BLADE
# 110  373^9598^825^^                T2 FLAIR PROPELLER
# 111   258^628^825^^                         T2 GRE AX
# 112  422^2503^825^^                      T2 Propeller
# 113   19^8007^825^^                 T2* GRE EPI SENSE
# 114   19^8007^825^^              T2* GRE epi AX SENSE
# 115  450^2421^825^^                  T2W_FFE GRE HEMO
# 116  741^6005^825^^                       T2_AX_BLADE
# 117  487^2101^825^^                      TRA BLADE T2
# 118  922^2101^825^^                   TRA FLAIR BLADE
# 119  922^2101^825^^                      TRA T1 BLADE
# 120  869^2101^825^^                      TRA T2 BLADE
# 121  487^2101^825^^              TRAN 3D T1 GRE 2.5MM
# 122  869^2101^825^^  TRAN 3D T1 GRE 2.5MM++NO ANGLE++
# 123  662^2101^825^^                TRAN 3D T1 GRE 2MM
# 124   106^801^825^^            ax flair blade -motion
# 125   106^801^825^^             ax t2 fs blade-motion
# 126  382^8907^825^^                    eBRN AX T2 GRE
# 127  624^5915^825^^                eT1 FLAIR AX SENSE
# 128  373^9598^825^^               head3-pl T2* FGRE S
# 129  222^7859^825^^                    t1 axial BLADE
# 130  899^3495^825^^              t1_blade_tra_dark-fl
# 131  899^3495^825^^              t1_blade_tra_fs post
# 132  673^2514^825^^               t1_mpr_tra_pat2_iso
# 133  266^2514^825^^           t1_mpr_tra_pat2_iso_FIL
# 134  899^3495^825^^                   t2_blade_fs_tra
# 135  490^2408^825^^                  t2_blade_tra_320
# 136  899^3495^825^^              t2_blade_tra_dark-fl
# 137  751^6401^825^^          t2_blade_tra_dark-fl_4mm
#
#                                               raw_path
# 0    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 2    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 3    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 4    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 6    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 7    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 8    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 9    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 10   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 11   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 12   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 13   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 14   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 15   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 16   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 17   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 18   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 19   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 20   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 21   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 22   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 23   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 24   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 25   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 26   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 27   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 28   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 29   /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# ..                                                 ...
# 108  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 109  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 110  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 111  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 112  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 113  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 114  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 115  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 116  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 117  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 118  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 119  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 120  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 121  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 122  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 123  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 124  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 125  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 126  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 127  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 128  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 129  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 130  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 131  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 132  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 133  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 134  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 135  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 136  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 137  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
# [138 rows x 3 columns]

# %%
multiple_mod_descriptions.to_csv("descriptions_unclassified_multiple_modalities.csv")

# %% [markdown]
# ##### No modality detected

# %% [markdown]
# List of descriptions for which we can't classify modality with multiple modalities

# %%
no_mod_images_fields = images_fields[images_fields.modality == 'N/A']
print(len(no_mod_images_fields.description.unique()))
print(len(no_mod_images_fields))
sorted(list(no_mod_images_fields.description.unique()))
# Out:
# 1216
# 5963
# ['',
#  '\n',
#  '(14760/13/1..24)-(14760/9/1..24)',
#  '(16219/10/1)-(16219/8/1)',
#  '(16291/9/1..24)-(16291/4/1..24)',
#  '* Brain    * DW/SSh',
#  '* Brain    *AX DE',
#  '* Brain    *SURVEY',
#  '**PG AX**',
#  '*AXIAL GRADIENT',
#  '*Ax PROBE-SV PRESS 35TE',
#  '*DIFFUSION QUIK GE',
#  '*FAST LOC FOR SPECTRO',
#  '*MST SURVEY',
#  '+ AX TENSOR 25',
#  '+ C AX 3D SPGR',
#  '+ PERFUSION AX',
#  '+ ax FSPGR BRAVO',
#  '+3D SPGR F/U METS/TUMOR',
#  '+AX BRAVO FSPGR 3D',
#  '+C  Ax STEALTH  bravo',
#  '+C  Ax bravo 3mm arc',
#  '+C 3D AXIAL,IRSPGR,Fast',
#  '+C AX 3D SPGR',
#  '+C AX FSPGR FATSAT',
#  '+C Ax PERF EPI 2:15min/20slice',
#  '+C EPI perf 2:15min (~20slices)',
#  '+C IR SPGR 3D VOLUMETRIC',
#  '+FSPGR 3D',
#  '+c Ax 3D FSPGR BRAVO 1x1x1',
#  '----CONTRAST----',
#  '..COR 1mm MPR sp GAD (from axial)',
#  '.6 SEC HELICAL SCAN',
#  '.6 SEC HELICAL W/IV',
#  '.AX MPR (from sag)',
#  '15CC POST GD* AX',
#  '2-Calibration Scan',
#  '2.0',
#  '20ML GD*AX',
#  '20ML POST GD* AX',
#  '20ML POST GD*AX',
#  '20ML*POST GD*AX',
#  '3 PL LOC',
#  '3 PLANE',
#  '3 PLANE LOC',
#  '3 PLN LOC',
#  '3 Pl. Loc',
#  '3 Plane LOC',
#  '3 Plane Loc',
#  '3 Plane Localizer',
#  '3 pl loc',
#  '3 pl.loc.',
#  '3 plane loc',
#  '3-D',
#  '3-P Loc',
#  '3-P,Localizer',
#  '3-PLANE LOC',
#  '3-PLN LOC',
#  '3-Pl Loc',
#  '3-pl',
#  '3-pl LOC',
#  '3-plane loc',
#  '3-plane localizer',
#  '3D AX MPR POST',
#  '3D AXIAL,IRSPGR,Fast',
#  '3D Ax FSPGR',
#  '3D BRAVO',
#  '3D DYN',
#  '3D FSPGR',
#  '3D SPGR AX C+',
#  '3D SPGR F/U METS/TUMOR',
#  '3D STEALTH W GAD',
#  '3P LOC',
#  '3PL LOC',
#  '3PLANE  LOC',
#  '3PLN LOC',
#  '3Pl Loc',
#  '3Plane Loc SSFSE',
#  '3pl loc',
#  "5'S AND 10'S",
#  '5-Ax FSE PD',
#  '500FOV Head  4.5  H30s',
#  '500FOV Head  4.5  H70h',
#  '6-Ax FSE PD',
#  '6. AX DW EPI',
#  '7-AXIAL GADO',
#  '7-FIBRE TRACK',
#  '7-GLOBAL GADO 2MM',
#  '8-AXIAL GADO',
#  '8-GLOBAL GADO',
#  '<3D Collection>',
#  '<DTI MPR FUSED[1]>',
#  '<LANGUAGE_AXIAL[1]>',
#  '<Lang axial2[1]>',
#  '<Lang sagittal2[1]>',
#  '<MIP Range>',
#  '<MIP Range[1]>',
#  '<MIP Range[2]>',
#  '<MIP Range[3]>',
#  '<MIP Range[4]>',
#  '<MOTOR_AXIAL[1]>',
#  '<MPR Range>',
#  '<MPR Range[1]>',
#  '<MPR Thick Range>',
#  '<MPR Thick Range[1]>',
#  '<Motor axial 2[1]>',
#  '<Motor sagittal 2[1]>',
#  'AAHScout',
#  'AAHScout_MPR_tra',
#  'AAScout',
#  'AAScout(Atlas)_BC',
#  'ADC',
#  'ADC Analysis-ADC',
#  'ADC Difference 21-Mar-2013 - 10-Jan-2013',
#  'ADC MAP',
#  'AIF',
#  'AIF (3 points)',
#  'ANONYMIZED',
#  'AP',
#  'AP Landscape',
#  'AREA MEASUREMENT',
#  'ASSET CAL',
#  'ASSET CALIB.',
#  'ASSET Cal',
#  'ASSET cal',
#  'ASSET calibration',
#  'ASSETCal-2 SLICES ABOVE SKULL',
#  'AUTO TTP',
#  'AX  DIFF',
#  'AX  DIFF_ADC',
#  'AX *PWI MATCH*',
#  'AX 2D GE',
#  'AX 3D FF3',
#  'AX 3D FSPGR +16mL',
#  'AX 3D FSPGR +18mL',
#  'AX 3D FSPGR straight+C',
#  'AX 3D SPGR',
#  'AX 3D SPGR + C',
#  'AX 3D SPGR +C',
#  'AX 3D SPGR POST',
#  'AX 3D SPGR PRE',
#  'AX 3D SPGR Post-Gad',
#  'AX 3D SPGR+C',
#  'AX 3D STRYKER 8-24-09',
#  'AX 3D+C,SPGR',
#  'AX 3D-SPGR *S T E  A  L T H*',
#  'AX ASL',
#  'AX ASL PERFUSION',
#  'AX B1000',
#  'AX BOLD',
#  'AX BONE',
#  'AX BRAINLAB +C',
#  'AX CUBE REFORMAT',
#  'AX DFSE BRAIN',
#  'AX DIFF',
#  'AX DIFF 1500 b value',
#  'AX DIFF 1500 b value_ADC',
#  'AX DIFF 2000 b value',
#  'AX DIFF 2000 b value_ADC',
#  'AX DIFF ASSET',
#  'AX DIFF EPI',
#  'AX DIFF TRACE ADC',
#  'AX DIFF TRACE ADC_ADC',
#  'AX DIFFUSION',
#  'AX DIFFUSION SENSE',
#  'AX DIFFUSION_ADC',
#  'AX DIFF_ADC',
#  'AX DIFF_TRACEW',
#  'AX DIFUSION',
#  'AX DTI',
#  'AX DTI_ADC',
#  'AX DTI_ColFA',
#  'AX DTI_EXP',
#  'AX DTI_FA',
#  'AX DTI_TRACEW',
#  'AX DW',
#  'AX DW EPI',
#  'AX EPI',
#  'AX EPI GAD',
#  'AX EPI PERFUSION TPEN',
#  'AX FFE',
#  'AX FL',
#  'AX FLR',
#  'AX FSE PD',
#  'AX FSPGR POST',
#  'AX GRADIENT',
#  'AX IR',
#  'AX IR SPGR REFORMAT',
#  'AX MERGE',
#  'AX MPGR',
#  'AX MRS/SPECT MV',
#  'AX MULTI VOXEL MRS',
#  'AX MULTI Voxel 144 TE',
#  'AX OBL 3D FSPGR',
#  'AX OBL DIFFUSION',
#  'AX PD',
#  'AX PERFUSION',
#  'AX PERFUSION (DSC)',
#  'AX PERFUSION 12 SLICES',
#  'AX PERFUSION EPI',
#  'AX PERFUSION_GBP',
#  'AX PERFUSION_PBP',
#  'AX PERFUSION_RELCBF',
#  'AX PERFUSION_RELCBV',
#  'AX PERFUSION_RELMTT',
#  'AX PERFUSION_TTP',
#  'AX POST IR',
#  'AX PWI +C',
#  'AX RECON',
#  'AX REFORMAT',
#  'AX ST',
#  'AX SV 144TE (OVER TUMOR)',
#  'AX SV 35 TE (OVER TUMOR)',
#  'AX SWAN',
#  'AX SWAN REFORMAT',
#  'AX SWI',
#  'AX TOF 3D COW (slow flow)_MIP_TRA',
#  'AX Tensor 21 directions 1000b',
#  'AXIAL',
#  'AXIAL  PD',
#  'AXIAL COLOR PET BRAIN',
#  'AXIAL DIFFUSION',
#  'AXIAL DIFFUSION_ADC',
#  'AXIAL EPI GRADIENT ECHO',
#  'AXIAL HEAD',
#  'AXIAL HEMO',
#  'AXIAL IMAGES',
#  'AXIAL MPGR',
#  'AXIAL PERFUSION',
#  'AXIAL PET 2MM BRAIN',
#  'AXIAL PET 2mm',
#  'AXIAL PET 4MM',
#  'AXIAL PET BRAIN',
#  'AXIAL PET/CT 2MM BRAIN',
#  'AXIAL PET/CT 2mm',
#  'AXIAL PET/CT 4MM',
#  'AXIAL PET/MR FDG BRAIN FUSION',
#  'AXIAL PWI POST',
#  'AXIAL PWI POST HEAD',
#  'AXIAL RECON',
#  'AXIAL SCANS HEAD RAD PLANNING',
#  'AXIAL SPGR',
#  'AXIAL VIBE RECON',
#  'AXIAL W',
#  'AXIAL W/',
#  'AX_DIFFUSION',
#  'AX_DIFFUSION_ADC',
#  'AX_FL3D',
#  'AX_PERFUSION',
#  'Adv Sim RT Plans',
#  'Adv Sim RT Structure Sets',
#  'Apparent Diffusion Coefficien',
#  'Apparent Diffusion Coefficient',
#  'Apparent Diffusion Coefficient (m??/s)',
#  'Apparent Diffusion Coefficient (mm2/s)',
#  'Apparent Diffusion Coefficient (mm?/s)',
#  'Apparent Diffusion Coefficient (mm²/s)',
#  'Autoperf Summary',
#  'Average',
#  'Average DC',
#  'Average DC EPI ASSET',
#  'Average DCET (Short)',
#  'Average DCR 25',
#  'Average DCirections',
#  'Average DConly',
#  'Ax  DW-EPI  b=1000',
#  'Ax  SPGR POST 19ML',
#  'Ax +C 20ML',
#  'Ax 2DTOF SPGR CAROTID',
#  'Ax 3D BRAVO Post',
#  'Ax 3D FSPGR',
#  'Ax 3D FSPGR +C',
#  'Ax 3D FSPGR Asset',
#  'Ax 3D SPGR +C',
#  'Ax 3D SPGR pre',
#  'Ax 3D SWAN',
#  'Ax 3D SWAN lower',
#  'Ax 3D SWAN upper',
#  'Ax 3D fastspgr POST',
#  'Ax DIFF',
#  'Ax DIFFUSION',
#  'Ax DTI',
#  'Ax DTI 6dir',
#  'Ax DTI NEURO ONLY',
#  'Ax Diffusion',
#  'Ax FSPGR 3D',
#  'Ax FSPGR 3D c+',
#  'Ax FSPGR 3D-Navigator',
#  'Ax FSPGR BRAVO',
#  'Ax FSPGR BRAVO FEDUCIAL (SC)',
#  'Ax FSPGR BRAVO POST (SC)',
#  'Ax FSPGR BRAVO Post contrast',
#  'Ax FSPGR BRAVO Pre contrast',
#  'Ax FSPGR BRAVO contrast',
#  'Ax MPGR',
#  'Ax PD',
#  'Ax PD FSE',
#  'Ax POST GAD',
#  'Ax PROBE-SV PRESS 35TE',
#  'Ax PROBE-SV PRESS,144TE S',
#  'Ax Post Contrast IR',
#  'Ax SUSCEPT(BLEED, TRAUMA)',
#  'Ax SV 144TE UN affected',
#  'Ax SV 144TE affected',
#  'Ax SWAN',
#  'Ax SWI',
#  'Ax Subtracted (10-8)',
#  'Ax bravo 3mm arc',
#  'Ax post rfmt',
#  'Ax rfmt .9/.9',
#  'Axial',
#  'Axial BSI',
#  'Axial CT',
#  'Axial DW-EPI',
#  'Axial DW-EPI_ADC',
#  'Axial Diffusion',
#  'Axial Diffusion_ADC',
#  'Axial FUSED',
#  'Axial PD FSE',
#  'Axial PET',
#  'Axial SWI',
#  'Axial VASC-EPI',
#  'Axial diffusion',
#  'Axial reformat IR',
#  'Axial reformat swan',
#  'B 0',
#  'B 1000',
#  'B 500',
#  'B-1000',
#  'B0',
#  'B1000',
#  'B1000 TRA',
#  'B1000I',
#  'B1001',
#  'B500',
#  'BONE',
#  'BONE 4.8  H70h',
#  'BONE Bone 3.0 PRE',
#  'BRAIN',
#  'BRAIN 5X5',
#  'BRAIN AX FSPGR 3D',
#  'BRAIN CT',
#  'BRAIN CT W-WO CONTRAST',
#  'BRAIN EMISSION',
#  'BRAIN Head 3.0 POST CE',
#  'BRAIN Head 3.0 PRE',
#  'BRAIN IMAGING-FUNCTIONAL-THALLIU',
#  'BRAIN LAB',
#  'BRAIN NON',
#  'BRAIN PLAIN',
#  'BRAIN SPECT',
#  'BRAIN W CONTRAST',
#  'BRAIN W WO',
#  'BRAIN W/O',
#  'BRAIN WITH CONTRAST',
#  'BRAIN WITH CONTRAST BONE',
#  'BRAIN_ROUTINE/EPI_DIFFUSIO',
#  'BRAIN_ROUTINE/SCOUT',
#  'BSI-minIP',
#  'Blood Flow (Relative)',
#  'Blood Volume (Relative)',
#  'Bone 2.5 & 5 mm',
#  'Bone 3.0',
#  'Bone 5.0',
#  'Brain',
#  'Brain      DW/SSh#',
#  'Brain      SURVEY/MST',
#  'Brain  4.8  H31s',
#  'Brain  4.8  H70h bone',
#  'Brain 2.5 & 5 mm',
#  'Brain 2.5 & 5 mm with iv',
#  'Brain 5mm  4.5  H41s',
#  'Brain 5mm  4.5  H60s',
#  'Brain w/wo Contrast',
#  'C+AX 3D SPGR',
#  'CAL SCAN',
#  'CAL SCAN 8CTL456',
#  'CALIB 8HRBRAIN',
#  'CALIB SCAN',
#  'CBF',
#  'CBF_RGB',
#  'CBV',
#  'CBV_2',
#  'CBV_RGB',
#  'CCBV',
#  'CCBV_Research',
#  'CO 3D FSPGR +C',
#  'CONTRAST',
#  'COW 3D',
#  'CT BRAIN',
#  'CT Brain 3.0 H31s',
#  'CT HEAD SCOUT',
#  'CT Head or Brain w/o Contrast',
#  'CT SCOUT HEAD IN',
#  'CT WB  4.0  B30f',
#  'CT_AXIAL_WO',
#  'C_Spine  2.0  B30s',
#  'C_Spine  2.0  B60s',
#  'Cal Scan',
#  'Cal.Scan',
#  'Calibration',
#  'Calibration Scan',
#  'CalibrationScan',
#  'Chest lat',
#  'Chest pa',
#  'Contrast Difference 21-Mar-2013 - 10-Jan-2013',
#  'Coronals',
#  'D6. AX FSPGR',
#  'D7. AX BRAVO',
#  'DCE 50 phases',
#  'DCE FA 10',
#  'DCE FA 15',
#  'DCE FA 2',
#  'DCE FA 20',
#  'DCE FA 30',
#  'DCE SINGLE DOSE',
#  'DCE main',
#  'DCE main-after 24 sec',
#  'DCE with FA 10',
#  'DCE with FA 15',
#  'DCE with FA 2',
#  'DCE with FA 20',
#  'DCE_2eco',
#  'DDW/ADC',
#  'DDW/SSh#',
#  'DEFAULT PS SERIES',
#  'DEMRI POST',
#  'DEMRI POST SENSE',
#  'DEMRI PRE',
#  'DEMRI PRE SENSE',
#  'DIFF NEW AUG 07',
#  'DIFF NEW AUG 07_ADC',
#  'DIFFUSION',
#  'DIFFUSION  3D TRACE_ADC',
#  'DIFFUSION  B0-B1000',
#  'DIFFUSION  B0-B1000_ADC',
#  'DIFFUSION 3MM',
#  'DIFFUSION 3MM_ADC',
#  'DIFFUSION AND ADC',
#  'DIFFUSION AND ADC_ADC',
#  'DIFFUSION AX',
#  'DIFFUSION AX TRACE ADC',
#  'DIFFUSION AX TRACE ADC_ADC',
#  'DIFFUSION AXIAL',
#  'DIFFUSION AXIAL_ADC',
#  'DIFFUSION AX_ADC',
#  'DIFFUSION SHC',
#  'DIFFUSION TENSOR',
#  'DIFFUSION TENSOR_ColFA',
#  'DIFFUSION TENSOR_FA',
#  'DIFFUSION TRACE ADC MAP',
#  'DIFFUSION TRACE ADC MAP_ADC',
#  'DIFFUSION_ADC',
#  'DIFFUSSION',
#  'DOCUMENTS',
#  'DOSE REPORT',
#  'DSC-Perfusion-24 delay',
#  'DSC-Perfusion-39 delay',
#  'DSCp3_MP mosaic_Echo_01',
#  'DSCp3_MP mosaic_Echo_01_P',
#  'DSCp3_MP mosaic_Echo_02',
#  'DSCp3_MP mosaic_Echo_02_P',
#  'DTI',
#  'DTI DIFF',
#  'DTI MPR',
#  'DTI MPR2',
#  'DTI N=27',
#  'DTI Neuro only',
#  'DTI mosaic',
#  'DTI25dir_b1400_lgFOV_av1',
#  'DTI25dir_b1400_lgFOV_av1_ADC',
#  'DTI25dir_b1400_lgFOV_av1_FA',
#  'DTI_1.5T_6Dir_tensor',
#  'DTI_1.5T_6Dir_tensor_ADC',
#  'DTI_1.5T_6Dir_tensor_TRACEW',
#  'DTI_12dir_1000b_3T_tensor',
#  'DTI_12dir_1000b_3T_tensor_ADC',
#  'DTI_12dir_1000b_3T_tensor_ColFA',
#  'DTI_12dir_1000b_3T_tensor_FA',
#  'DTI_12dir_1000b_3T_tensor_TRACEW',
#  'DTI_3D_IMAGE3',
#  'DW',
#  'DW EPI',
#  'DW EPI ASSET',
#  'DW EPI ECHO/SPEED',
#  'DW EPI EchoSpeed',
#  'DW SSh W/ADC',
#  'DW TRA',
#  'DW/SSh FL',
#  'DW_SSh_og',
#  'Delay map -Leakage corrected',
#  'Design',
#  'Diff',
#  'Diffusion',
#  'Diffusion 3-scan Trace',
#  'Diffusion 3-scan Trace_ADC',
#  'Diffusion Weighted',
#  'Diffusion- NO SCIC',
#  'Diffusion_ADC',
#  'Diffusion_Series_TraceW_[1]',
#  'Documents',
#  'Dose Info',
#  'Dose Report',
#  'Dynamic Susceptibility Imaging',
#  'EGFR',
#  'EP2D PERF.  (GE REPLACE)',
#  'EP2D_DIFFUSION_AX',
#  'EP2D_DIFFUSION_AX_ADC',
#  'EP2D_DIFF_3SCAN_TRACE_192_FIL_1',
#  'EPI GE AX',
#  'EXP',
#  'Enhancement curve',
#  'EvaSeries_GLM',
#  'Exam/Series Text Page',
#  'Exponential Apparent Diffusio',
#  'Exponential Apparent Diffusion Coefficient',
#  'FA',
#  'FA (color)',
#  'FA color',
#  'FAST LOC FOR SPECTRO',
#  'FFE FOR BLEED',
#  'FL:C/3 PL LOC',
#  'FL:E/3DTOF 3 slab HR',
#  'FMT (color)',
#  'FSPGR 3D',
#  'FSPGR 3D +C',
#  'FSPGR 3D C+',
#  'FSPGR 3D IR POST',
#  'FUSED PET CT AX',
#  'Finger Tapping(t-test, MC)',
#  'Fractional Aniso.',
#  'Fractional Ansio.',
#  'Fractional Ansio.SET',
#  'Fractional Ansio.ns',
#  'Fractional Ansio.rt)',
#  'Fused Sagittal [BR_CTAC] Brain 3/23/2011 12:06:53 PM',
#  'Fused Transverse [BR_CTAC] Brain 3/23/2011 12:06:48 PM',
#  'GAD 3D FFECOR',
#  'GAD_MTC',
#  'GE AX 30TE',
#  'GRAD HEMO',
#  'HASTE LOCALIZER',
#  'HASTE LOCALIZER_COMP_SP_-101',
#  'HEAD',
#  'HEAD 2.5 & 5 MM',
#  'HEAD 5.0 BONE',
#  'HEAD 5.0 SOFT',
#  'HEAD AND NECK',
#  'HEAD BL',
#  'HEAD BONE',
#  'HEAD BW',
#  'HEAD POST  4.8  H30s',
#  'HEAD PRE  4.8  H30s',
#  'HEAD ST',
#  'HEAD W /IV',
#  'HEAD W/O IVC',
#  'HEAD-post  4.8  H30s',
#  'HEAD-pre  4.8  H30s',
#  'HELICAL HEAD',
#  'HEMO',
#  'Head 3.0',
#  'Head 3.0  CE',
#  'Head 3.0 POST Sagittal CE',
#  'Head 5.0',
#  'Head W  2.0  H31s',
#  'Head WO  2.0  H31s',
#  'Head axial',
#  'Head axial  4.5  H31s',
#  'Head axial BONE',
#  'Head post',
#  'Head w/',
#  'Head w/ Bone',
#  'Head w/o',
#  'Head w/o BONE',
#  'Head with C  4.5  H31s',
#  'Head with C  4.5  H60s',
#  'Head with IV Contrast   5.0  H30s',
#  'Head with IV Contrast   5.0  H70h',
#  'Head without IV contrast  5.0  H30s',
#  'Head wo  4.8  H41Soft tissue',
#  'Head wo  4.8  H70 bone',
#  'HeadSeq',
#  'HeadSeq  bone',
#  'HeadSeq  soft tissue',
#  'HeadSeq Bone',
#  'HeadSeq W',
#  'HeadSeq W/O',
#  'HeadSeq W/O Bone',
#  'IR SPGR 3D VOLUMETRIC',
#  'Isotropic image',
#  'JEREMY HOPKIN  1',
#  'JEREMY HOPKIN DR',
#  'K2',
#  'K2_research',
#  'KO: MRI-BRAIN W/WO CONTRAST',
#  'Key Images',
#  'LOC',
#  'LOC 1',
#  'LOC 3 PLANE',
#  'LOCALIZER',
#  'LOWB',
#  'LT side leison',
#  'LT.  RECON',
#  'Loc',
#  'Loc 3-Plane',
#  'Localizer',
#  'Lung',
#  'MEFLASH_10_20_75deg FA  10.0',
#  'MEFLASH_10_20_75deg FA  10.0 RMS',
#  'MEFLASH_10_20_75deg FA  10.0_P',
#  'MEFLASH_10_20_75deg FA  20.0',
#  'MEFLASH_10_20_75deg FA  20.0 RMS',
#  'MEFLASH_10_20_75deg FA  20.0_P',
#  'MEFLASH_10_20_75deg FA  75.0',
#  'MEFLASH_10_20_75deg FA  75.0 RMS',
#  'MEFLASH_10_20_75deg FA  75.0_P',
#  'MIP',
#  'MIP [BR_CTAC] Brain 3/23/2011 12:06:51 PM',
#  'MIPn',
#  'MIPy',
#  'MMIL MULTISHELL DIFFUSION',
#  'MONTAGE',
#  'MONTOYA AIF POINTS',
#  'MONTOYA NAWM #1',
#  'MONTOYA NAWM #2',
#  'MP RAGE AXIAL',
#  'MP RAGE AXIAL 3MM +C',
#  'MP RAGE AXIAL 3MM PRE',
#  'MP RAGE AXIAL GAD',
#  'MPR AXIAL POST',
#  'MPR, AXIAL',
#  'MPRaxial',
#  'MPRcoronal',
#  'MR BRAIN MRA WWO',
#  'MR BRAIN W   W/O CONTRAST',
#  'MR BRAIN WO&W CONTRAST (MR-10)',
#  'MR BRAIN/HEAD WO/W CON',
#  'MR Brain Routine wo and w contrast',
#  'MR HEAD W & WO CONTRAST (MR-10)',
#  'MR IMAGE GUIDED BRAIN W CONTRAST (Stealth) (MR-31)',
#  'MRA BRAIN',
#  'MRI BRAIN W AND W/O CON',
#  'MRI BRAIN W AND W/O CONTRAST',
#  'MRI BRAIN W CONT',
#  'MRI BRAIN W CONTRAST',
#  'MRI BRAIN W&WO/CONTRAST',
#  'MRI BRAIN W-O CONTRAST',
#  'MRI BRAIN W-WO CONTRAST',
#  'MRI BRAIN W/WO',
#  'MRI BRAIN WW C',
#  'MRI BRAIN/BR STM WO/W CON',
#  'MRI Brain With And Without Contrast',
#  'MRI Brain With Contrast',
#  'MRI Brain w/ + w/o Contrast',
#  'MRI Brain w/ Planning',
#  'MRI Brain wo/w contrast',
#  'MRI HEAD W AND W/O CONTRAST',
#  'MROMI_mag_FirstECHO',
#  'MROMI_mag_SecondECHO',
#  'MRS/SPECT MV',
#  'MRV POST ROTATE',
#  'MRV POST TUMBLE',
#  'MRV ROTATE',
#  'MRV TUMBLE',
#  'MTT',
#  'MTT map -Leakage corrected',
#  'MTT(CVP) (color)',
#  'MTT_RGB',
#  'MULTISHELL - Colored Orientation',
#  'Mag_Images',
#  'Mean Time to Enhance',
#  'Mean Transit Time',
#  'Mean_&_t-Maps',
#  'MoCoSeries',
#  'Monitoring  10.0  B40s',
#  'Motor activation 2',
#  'N/A',
#  'NOB SURVEY',
#  'Negative Enhancement Integral',
#  'O-Ax dynEPI SE-EPI S',
#  'OLDROYD MIKE MD',
#  'OLIVERIO^CHARLES^A^^',
#  'OLIVERIO^CHARLES^A^^ 1',
#  'ORDONNANCE',
#  'Ob_Ax_I -> S_Average_sp:5.0_th:5.0',
#  'PAPERWORK',
#  'PBP_ep2d_perf_p2',
#  'PDW_TSE',
#  'PE',
#  'PE  2.0  B30f',
#  'PERFUSION',
#  'PERFUSION (1.5 -T)',
#  'PERFUSION (1.5 -T)_RELCBF',
#  'PERFUSION (1.5 -T)_RELCBV',
#  'PERFUSION (1.5 -T)_RELMTT',
#  'PERFUSION (1.5 -T)_TTP',
#  'PERFUSION Field Map',
#  'PERFUSION POST',
#  'PERFUSION SCAN DYN',
#  'PERFUSION SCAN DYN- STRAIGHT',
#  'PERFUSION SENSE',
#  'PERFUSION_GBP',
#  'PERFUSION_PBP',
#  'PERFUSION_TTP',
#  'PET AC 2D',
#  'PET AC 3DBRAIN',
#  'PET BRAIN',
#  'PET Brain',
#  'PET MIP',
#  'PET NAC 2D',
#  'PET NAC 3DBRAIN',
#  'PET WB',
#  'PET WB UNCORRECTED',
#  'PJN',
#  'POST',
#  'POST AX',
#  'POST AX 3D SPGR',
#  'POST AX MT',
#  'POST AX MTC',
#  'POST GD* AX',
#  'POST GD*AX 20 MLS',
#  'POST INFUSION',
#  'POST MTC',
#  'POST TI AX FLOW COMP',
#  'POST TUMBLE',
#  'PR for KO: MRI-BRAIN W/WO CONTRAST',
#  'PRESS  288TE,1104TR',
#  'PRESS  35TE,1500TR',
#  'PRESS 144TE,1000TR',
#  'PROBE 3D CSI',
#  'PROBE-SI 144',
#  'PROBE-SV 144  Contra',
#  'PROBE-SV 144  Lesion',
#  'PROBE-SV 35 CONTRALAT',
#  'PROBE-SV 35 Contra',
#  'PROBE-SV 35 LESION',
#  'PROBE-SV 35 Lesion',
#  'PROP ADC',
#  'PROP COMB',
#  'PROP eADC',
#  'Paper',
#  'Patient Aligned MPR',
#  'Patient Aligned MPR AWPLAN_SMARTPLAN_TYPE_BRAIN',
#  'Patient Info',
#  'Patient Protocol',
#  'Perfusion',
#  'Perfusion ROIs',
#  'Perfusion_Weighted',
#  'Pha_Images',
#  'PhoenixZIPReport',
#  'PosDisp: [3] Diffusion',
#  'Post Ax 3D FSPGR',
#  'PreMonitoring  10.0  B40s',
#  'Processed Images',
#  'QUANTITATIVE',
#  'RAD PLANNING HEAD',
#  'RCBF_RGB',
#  'RCBV',
#  'RCBV see notes below',
#  'RCBV_RGB',
#  'RECON BONE',
#  'REF2',
#  'REFORMAT',
#  'REL CBV_RGB',
#  'REL MTT_RGB',
#  'REL-CBF_RGB',
#  'RELCBF2_RGB',
#  'RELCBF_GLOBAL_ep2d_perf_p2',
#  'RELCBV2_RGB',
#  'RELCBV_GLOBAL_ep2d_perf_p2',
#  'RELMTT_GLOBAL_ep2d_perf_p2',
#  'RELMTT_RGB',
#  'RMTT_RGB',
#  'ROIsComp',
#  'ROUTINE HEAD',
#  'ROUTINE/MPGR-AX',
#  'ROUTINE/MPGR-AXIAL',
#  'ROUTINE/SCOUT',
#  'RT side normal',
#  'RT.  RECON',
#  'RTN/AX-FLR',
#  'RTN/DIFF-MAP',
#  'RTN/DIFF-TRACE',
#  'RTN/SCOUT',
#  'RUN IN RESEARCH MODE',
#  'Recon 2:  AXIAL',
#  'Recon 2:  POST',
#  "Recon 2: 5'S AND 10'S",
#  'Recon 2: AXIAL',
#  'Recon 2: Axial',
#  'Recon 2: CT BRAIN',
#  'Recon 2: CT_AXIAL_WO',
#  'Recon 2: HEAD W /IV',
#  'Recon 2: HELICAL HEAD',
#  'Recon 2: Routine Head',
#  'Recon 2: TRAUMA HEAD',
#  'Recon 2: W/ IV CONTRAST',
#  'Recon 2: WITH CONTRAST',
#  'Recon 3:  POST',
#  'Ref of VASC-EPI-minIP',
#  'Reformatted',
#  'Reg - DIFFUSION SENSE',
#  'Reg - WIP DTI 2X2X2 SENSE',
#  'Reg - WIP DTI SENSE',
#  'Results Folder (Capture)',
#  'Routine Head',
#  'Routine Seq 5.0 H30s',
#  'SAGITTAL',
#  'SAGITTAL COLOR PET BRAIN',
#  'SAGITTAL CT 1.5MM',
#  'SAGITTAL CT 2MM BRAIN',
#  'SAGITTAL CT 2mm',
#  'SAGITTAL FSPGR POST',
#  'SAGITTAL PET 2MM BRAIN',
#  'SAGITTAL PET 2mm',
#  'SAGITTAL PET 4MM',
#  'SAGITTAL PET BRAIN',
#  'SAGITTAL PET/CT 2MM BRAIN',
#  'SAGITTAL PET/CT 2mm',
#  'SAGITTAL PET/CT 4MM',
#  'SAGITTAL PET/MR FDG BRAIN FUSION',
#  'SAGITTAL01',
#  'SAGMPR',
#  'SC',
#  'SC   ASSET Cal',
#  'SCHLAPPI TONGUE+FINGERTAP+TOETAP',
#  'SCOUT',
#  'SCOUT AP/LAT',
#  'SCOUTS',
#  'SCRAPBOOK',
#  'SCREENSAVE',
#  'SD',
#  'SPECTRO AX SV 35 ABNORM 8 CH COIL',
#  'SPECTROSCOPY MULTI VOXEL',
#  'SPECTROSCOPY SINGLE VOXEL',
#  'STEALTH BRAIN',
#  'STEALTH HEAD',
#  'STEALTH SCOUT',
#  'STEALTH/SCOUT',
#  'STRAIGHT AX LOC',
#  'STRYKER 2010',
#  'SUB_S8-S6_1',
#  'SURV',
#  'SURVEY',
#  'SURVEY 3PL',
#  'SURVEY/HEAD',
#  'SURVEY/MST',
#  'SV 35 TE  Abnormal side 2x2x2',
#  'SV 35 TE S0.3  RT LAT side 2x2x2',
#  'SV 35 TE S0.3  RT side 2x2x2',
#  'SV 35 TE S15.3  Abnormal side 2x2x2',
#  'SV 35 TE S15.3  RT side 2x2x2',
#  'SV 35 TE S30  ABN side 2x2x2',
#  'SV 35 TE S30 ABN side 2x2x2',
#  'SV 35 TE S30 RT side 2x2x2',
#  'SWAN REFORMAT',
#  'SWAN RFMT',
#  'SWI',
#  'SWI (MIN REFORMAT)',
#  'SWI AX MIP MPGR',
#  'SWI MIN REFORMAT',
#  'SWI_Images',
#  'SagSTRYKER',
#  'Sagittal PET',
#  'Sagittal PET MAG',
#  'Sagittals',
#  'Scanogram SCA',
#  'Scout',
#  'Scout AP-0',
#  'Screen Save',
#  'Screen save',
#  'Seg Structural Auditory',
#  'Seg Structural Speech-Phonetic-Rhyming',
#  'Sieluzycki, Michal AIF Point#1',
#  'Sieluzycki, Michal AIF Point#2',
#  'Sieluzycki, Michal AIF Point#3',
#  'Sieluzycki, Michal AIF Point#4',
#  'Sieluzycki, Michal AIF Point#5',
#  'Sieluzycki, Michal NAWM',
#  'SmartBrain',
#  'StartFMRI',
#  'Std 5 mm',
#  'Std 5 mm with iv',
#  'Stealth+Gad',
#  'Summary Series',
#  'Survey',
#  'Survey_MST',
#  'Survey_NV_head_only',
#  'Survey_SHC',
#  'TENSOR',
#  'TENSOR 3mm',
#  'TENSOR 6 directions',
#  'TENSOR ASSET (Short)',
#  'TENSOR/ 2D EPI ASSET',
#  'TI AX SE POST',
#  'TOF_3D_multi-slab',
#  'TOMO',
#  'TRA DIFFUSION',
#  'TRA DIFFUSION MDDW 12',
#  'TRA DIFFUSION MDDW 12_ADC',
#  'TRA DIFFUSION MDDW 12_ColFA',
#  'TRA DIFFUSION MDDW 12_FA',
#  'TRA DIFFUSION MDDW 12_TRACEW',
#  'TRA DIFFUSION++NO ANGLE++',
#  'TRA DIFFUSION++NO ANGLE++_ADC',
#  'TRA DIFFUSION_ADC',
#  'TRA DIFFUSION_ColFA',
#  'TRA DIFFUSION_FA',
#  'TRA DIFFUSION_TRACEW',
#  'TRA DTI',
#  'TRA DTI_ADC',
#  'TRA DTI_ColFA',
#  'TRA DTI_FA',
#  'TRA DTI_TRACEW',
#  'TRA PERFUSION',
#  'TRA PERFUSION++NO ANGLE++',
#  'TRA PERFUSION++NO ANGLE++_GBP',
#  'TRA PERFUSION++NO ANGLE++_PBP',
#  'TRA PERFUSION++NO ANGLE++_RELCBF',
#  'TRA PERFUSION++NO ANGLE++_RELCBV',
#  'TRA PERFUSION++NO ANGLE++_RELMTT',
#  'TRA PERFUSION++NO ANGLE++_TTP',
#  'TRA PERFUSION+NO ANGLE+_RELCBF',
#  'TRA PERFUSION+NO ANGLE+_RELCBV',
#  'TRA PERFUSION+NO ANGLE+_RELMTT',
#  'TRA PERFUSION+NO ANGLE+_TTP',
#  'TRA PERFUSION_GBP',
#  'TRA PERFUSION_PBP',
#  'TRA PERFUSION_RELCBF',
#  'TRA PERFUSION_RELCBV',
#  'TRA PERFUSION_RELMTT',
#  'TRA PERFUSION_TTP',
#  'TRA SWI',
#  'TRA fMRI LANGUAGE',
#  'TRA fMRI MOTOR',
#  'TRACE',
#  'TRACE  DIFFUSION',
#  'TRACE  DIFFUSION_ADC',
#  'TRAN DIFFUSION',
#  'TRAN DIFFUSION_ADC',
#  'TRANSVERSE',
#  'TRANSVERSE01',
#  'TRAUMA HEAD',
#  'TTP',
#  'TTP2_RGB',
#  'TTP_RGB',
#  'TTP_ep2d_perf_p2',
#  'TUMOR PERFUSION',
#  'TUMOR SPECT',
#  'TeachingCase images',
#  'Thorax  4.0  B70f',
#  'Three plane Loc',
#  'Time to Peak',
#  'Tmax (color)',
#  'ToF-3D-multi-slab',
#  'ToF-3D-multi-slab_MIP_TRA',
#  'ToF-3D_CAROTID',
#  'Topogram',
#  'Topogram  0.6  T80s',
#  'Trace',
#  'UMP 2.5MMX 2.5MM',
#  'UMP HELICAL',
#  'UTE_WIP580_1echo',
#  'VA15A_diff&ADC_3scan_trace',
#  'VA15A_diff&ADC_3scan_trace_ADC',
#  'VASC-EPI-minIP',
#  'VEN_BOLD',
#  'VEN_BOLD_3mm',
#  'VI Snapshot (0): +C IR SPGR 3D VOLUMETRIC',
#  'VIBE 3D WHOLE HEAD POST',
#  'VIBE 3D WHOLE HEAD POST_FIL',
#  'VVEN_BOLD mip',
#  'Visual Motor(t-test, MC)',
#  'W/ CONTRAST',
#  'W/ IV CONTRAST',
#  'W/O CONTRAST',
#  'WITH',
#  'WITH CONTRAST',
#  'WITHOUT',
#  'WOCNT',
#  'Z  C-S-T Scano',
#  'ZERO-B',
#  '[100] TRA DIFFUSION MDDW 12_TENSOR_OFFLINE_TRACTS_VOLUME[1]',
#  '[100] TRA DIFFUSION_TENSOR_OFFLINE_TRACTS_VOLUME[1]',
#  '[BR_CTAC] Brain',
#  '[BR_NAC] Brain',
#  'act_MoCoSeries',
#  'adc',
#  'aif',
#  'aif-roi location',
#  'asl_RGB',
#  'ax +c',
#  'ax 3d fastspgr+C',
#  'ax 3d fastspgr+gd',
#  'ax 3d spgr+gd',
#  'ax fse rpd',
#  'ax mpr ref',
#  'ax post rft',
#  'axial bravo',
#  'axial recon',
#  ...]

# %% [markdown]
# Description for which we can't classify between T1 post and T1 pre; and related DICOM folder paths.

# %%
no_mod_images_fields = no_mod_images_fields.loc[:, ["patient_id", "description", "raw_path"]].sort_values("description").reset_index(drop=True)
no_mod_images_fields
# Out:
#           patient_id              description  \
# 0      84^7504^825^^
# 1     114^7720^825^^
# 2      84^7504^825^^
# 3      84^7504^825^^
# 4     114^7720^825^^
# 5      84^7504^825^^
# 6     376^5915^825^^
# 7      84^7504^825^^
# 8      84^7504^825^^
# 9     376^5915^825^^
# 10    376^5915^825^^
# 11    340^2116^825^^
# 12     397^801^825^^
# 13    340^2116^825^^
# 14    426^5915^825^^
# 15     397^801^825^^
# 16    426^5915^825^^
# 17    920^3521^825^^
# 18    543^7705^825^^
# 19    543^7705^825^^
# 20     500^801^825^^
# 21    868^7821^825^^
# 22     84^7504^825^^
# 23     84^7504^825^^
# 24     500^801^825^^
# 25     84^7504^825^^
# 26    684^2116^825^^
# 27    684^2116^825^^
# 28    868^7821^825^^
# 29     84^7504^825^^
# ...              ...                      ...
# 5933  266^2514^825^^  svs_se_135 tumor proper
# 5934  266^2514^825^^  svs_se_135 tumor proper
# 5935  266^2514^825^^    svs_se_135 unaffected
# 5936  266^2514^825^^    svs_se_135 unaffected
# 5937  453^2443^825^^               svs_se_270
# 5938  453^2443^825^^               svs_se_270
# 5939  725^2101^825^^               svs_se_288
# 5940  725^2101^825^^               svs_se_288
# 5941  725^2101^825^^               svs_se_288
# 5942  725^2101^825^^               svs_se_288
# 5943  855^7915^825^^                   tB1000
# 5944  855^7915^825^^                   tB1000
# 5945  855^7915^825^^                   tB1000
# 5946  673^2514^825^^                    trace
# 5947  266^2514^825^^                    trace
# 5948  418^2514^825^^                    trace
# 5949  673^2514^825^^                    trace
# 5950  266^2514^825^^                    trace
# 5951  738^2514^825^^                    trace
# 5952  114^7720^825^^     trufi_multiplane_loc
# 5953  114^7720^825^^     trufi_multiplane_loc
# 5954  114^7720^825^^     trufi_multiplane_loc
# 5955  114^7720^825^^     trufi_multiplane_loc
# 5956  551^5901^825^^     trufi_multiplane_loc
# 5957  114^7720^825^^     trufi_multiplane_loc
# 5958  114^7720^825^^     trufi_multiplane_loc
# 5959  523^5702^825^^                      ttp
# 5960  266^2514^825^^                     ttp1
# 5961  266^2514^825^^                  ttp_RGB
# 5962  418^2514^825^^                  ttp_RGB
#
#                                                raw_path
# 0     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 2     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 3     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 4     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 6     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 7     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 8     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 9     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 10    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 11    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 12    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 13    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 14    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 15    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 16    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 17    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 18    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 19    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 20    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 21    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 22    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 23    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 24    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 25    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 26    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 27    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 28    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 29    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# ...                                                 ...
# 5933  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5934  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5935  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5936  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5937  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5938  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5939  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5940  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5941  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5942  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5943  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5944  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5945  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5946  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5947  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5948  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5949  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5950  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5951  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5952  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5953  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5954  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5955  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5956  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5957  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5958  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5959  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5960  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5961  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5962  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
# [5963 rows x 3 columns]

# %%
no_mod_images_fields.to_csv("images_unclassified_no_modalities.csv")

# %%
no_mod_descriptions = no_mod_images_fields.drop_duplicates("description").reset_index(drop=True)
no_mod_descriptions
# Out:
#           patient_id                        description  \
# 0      84^7504^825^^
# 1     392^7504^825^^                                 \n
# 2     729^5903^825^^   (14760/13/1..24)-(14760/9/1..24)
# 3     729^5903^825^^           (16219/10/1)-(16219/8/1)
# 4     778^3343^825^^    (16291/9/1..24)-(16291/4/1..24)
# 5      84^7504^825^^                * Brain    * DW/SSh
# 6      84^7504^825^^                  * Brain    *AX DE
# 7      84^7504^825^^                 * Brain    *SURVEY
# 8     696^6001^825^^                          **PG AX**
# 9     654^9598^825^^                    *AXIAL GRADIENT
# 10    966^1201^825^^            *Ax PROBE-SV PRESS 35TE
# 11    654^9598^825^^                 *DIFFUSION QUIK GE
# 12    966^1201^825^^              *FAST LOC FOR SPECTRO
# 13    598^3474^825^^                        *MST SURVEY
# 14    332^7729^825^^                     + AX TENSOR 25
# 15    935^2403^825^^                     + C AX 3D SPGR
# 16    276^7729^825^^                     + PERFUSION AX
# 17    332^7729^825^^                   + ax FSPGR BRAVO
# 18    668^7627^825^^            +3D SPGR F/U METS/TUMOR
# 19    961^7729^825^^                 +AX BRAVO FSPGR 3D
# 20     397^801^825^^              +C  Ax STEALTH  bravo
# 21     288^801^825^^               +C  Ax bravo 3mm arc
# 22    440^2503^825^^            +C 3D AXIAL,IRSPGR,Fast
# 23    348^2503^825^^                      +C AX 3D SPGR
# 24    421^2503^825^^                 +C AX FSPGR FATSAT
# 25    348^2503^825^^     +C Ax PERF EPI 2:15min/20slice
# 26    917^2503^825^^    +C EPI perf 2:15min (~20slices)
# 27     811^511^825^^           +C IR SPGR 3D VOLUMETRIC
# 28    541^7729^825^^                          +FSPGR 3D
# 29    881^3431^825^^         +c Ax 3D FSPGR BRAVO 1x1x1
# ...              ...                                ...
# 1186  266^2514^825^^                            relcbv1
# 1187  523^5702^825^^                             relmtt
# 1188  673^2514^825^^                           rmtt_RGB
# 1189   65^2421^825^^                               sB 0
# 1190  347^2421^825^^                         sB 0 IMAGE
# 1191  450^2421^825^^                            sB ZERO
# 1192   336^601^825^^                             sB1000
# 1193   336^601^825^^                                sBO
# 1194  347^2421^825^^                         sDIFFUSION
# 1195  450^2421^825^^                 sDIFFUSION (B1000)
# 1196  647^7848^825^^                              sDiff
# 1197  909^1514^825^^                                sb0
# 1198  909^1514^825^^                             sb1000
# 1199  344^7766^825^^                              scout
# 1200  639^1324^825^^              se epi perfusion post
# 1201   19^8007^825^^  strace Reg - DTI_medium_iso SENSE
# 1202   44^5901^825^^                             survey
# 1203  782^7825^825^^                         survey/MST
# 1204  343^3416^825^^                         svs_se_135
# 1205  266^2514^825^^                   svs_se_135 Edema
# 1206  266^2514^825^^            svs_se_135 tumor proper
# 1207  266^2514^825^^              svs_se_135 unaffected
# 1208  453^2443^825^^                         svs_se_270
# 1209  725^2101^825^^                         svs_se_288
# 1210  855^7915^825^^                             tB1000
# 1211  673^2514^825^^                              trace
# 1212  114^7720^825^^               trufi_multiplane_loc
# 1213  523^5702^825^^                                ttp
# 1214  266^2514^825^^                               ttp1
# 1215  266^2514^825^^                            ttp_RGB
#
#                                                raw_path
# 0     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 2     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 3     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 4     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 5     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 6     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 7     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 8     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 9     /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 10    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 11    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 12    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 13    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 14    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 15    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 16    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 17    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 18    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 19    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 20    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 21    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 22    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 23    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 24    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 25    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 26    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 27    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 28    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 29    /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# ...                                                 ...
# 1186  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1187  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1188  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1189  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1190  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1191  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1192  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1193  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1194  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1195  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1196  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1197  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1198  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1199  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1200  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1201  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1202  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1203  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1204  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1205  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1206  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1207  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1208  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1209  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1210  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1211  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1212  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1213  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1214  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
# 1215  /labs/gevaertlab/users/hackhack/RTOG/RTOG_dupl...
#
# [1216 rows x 3 columns]

# %%
no_mod_descriptions.to_csv("descriptions_unclassified_no_modalities.csv")
