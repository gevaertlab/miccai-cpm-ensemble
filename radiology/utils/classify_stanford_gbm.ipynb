# %%
import os

import re
import csv

import numpy as np
import pandas as pd

import dicom
from collections import Counter

import shutil

from data_utils import arr_to_im_path
from classify_utils import collect_info_patient_folder

# %%
data_dir = '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM'

# get the patient folders to classify
all_files_path = []
for patient in os.listdir(data_dir): 
    patient_path = os.path.join(data_dir, patient)
    if os.path.isdir(patient_path):
        folders = os.listdir(patient_path)
        folders = [os.path.join(patient_path, fold) for fold in folders]
        folders = [fold for fold in folders if os.path.isdir(fold)]
        patient_path = os.path.join(patient_path, folders[0])
        folders = folders = os.listdir(patient_path)
        folders = [os.path.join(patient_path, fold) for fold in folders]
        folders = [fold for fold in folders if os.path.isdir(fold)]
        all_files_path.extend(folders)

# %%
# check that all dicoms of the same folder have the same metadata
count = 0
weird = []
metadatas = []

for k, ex in enumerate(all_files_path):
    if k % 300 == 0:
        print('file %d out of %d'%(k + 1, len(all_files_path)))
    ex_dicoms = os.listdir(ex)
    ex_dicoms = [dic for dic in ex_dicoms if dic[-3:] == 'dcm']
    ex_dicoms = [os.path.join(ex, dic) for dic in ex_dicoms]
    metadata = set()
    for ex_dic in ex_dicoms:
        pat = dicom.read_file(ex_dic)
        try:
            patient_id = str(pat.PatientName)
            date = str(pat.AcquisitionDate)
            thickness = str(pat.SliceThickness)
            rows = int(pat.Rows)
            columns = int(pat.Columns)
            description = str(pat.SeriesDescription)
            all_info = (patient_id, date, thickness, rows, columns, description)
            metadata.add(all_info)
        except AttributeError:
            continue
    if len(metadata) != 1:
        weird.append(ex)
        count += 1
        metadatas.append(metadata)
# Out:
# file 1 out of 2315
# file 301 out of 2315
# file 601 out of 2315
# file 901 out of 2315
# file 1201 out of 2315
# file 1501 out of 2315
# file 1801 out of 2315
# file 2101 out of 2315

# %%
weird
# Out:
# ['/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-02 - Patient-02/Mr Stereotactic On-Call/RAPID Summary - 1161',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-02 - Patient-02/Mr Stereotactic On-Call/RAPID Summary - 1261',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-03 - Patient-03/Mr Brain Reference Only/PACS nomination form - 801',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-03 - Patient-03/Mr Brain Reference Only/Study acquired outside hospital - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-04 - Patient-04/Mr Brain Wandwo Contrast/RAPID Summary - 1161',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-04 - Patient-04/Mr Brain Wandwo Contrast/SCREENSAVE - 1000',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-05 - Patient-05/Mr Brain Reference Only/MRI BRAIN W CONTRAST - 999999',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-05 - Patient-05/Mr Brain Reference Only/MRI BRAIN WO CONTRAST - 999999999',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-05 - Patient-05/Mr Brain Reference Only/PACS nomination form - 801',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-05 - Patient-05/Mr Brain Reference Only/Study acquired outside hospital - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-06 - Patient-06/Mr Brain Reference Only/AX SWAN 6X2 - 802',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-06 - Patient-06/Mr Brain Reference Only/PACS nomination form - 801',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-06 - Patient-06/Mr Brain Reference Only/PAPERWORKS - 9999',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-06 - Patient-06/Mr Brain Reference Only/Study acquired outside hospital - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-07 - Patient-07/Mr Brain/RAPID Summary - 1261',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-07 - Patient-07/Mr Brain/SCREENSAVE - 1100',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-08 - Patient-08/Mr Brain Reference Only/PACS nomination form - 801',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-08 - Patient-08/Mr Brain Reference Only/Study acquired outside hospital - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient

#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-73 - Patient-73/Mr Brain Wandwo Contrast/Projection Images - 503',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-73 - Patient-73/Mr Brain Wandwo Contrast/Projection Images - 504',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-73 - Patient-73/Mr Brain Wandwo Contrast/Projection Images - 505',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-73 - Patient-73/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1206',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-76 - Patient-76/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1206',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/B CST (Capture) - 608',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/B CST color (Capture) - 607',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/Composite (Capture) - 605',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/CUBE AX REFORMAT - 601',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/CUBE COR REFORMAT - 602',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/isoDWI132-R3 - 502',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/L CST (Capture) - 602',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/Processed Images - 701',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/R CST (Capture) - 601',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/Sag Tegmental (Capture) - 604',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/SPGR AX REFORMAT - 703',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/SPGR COR REFORMAT - 702',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/SPGR COR REFORMAT - 704',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/Teg-P1 (Capture) - 606',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-80 - Patient-80/Lpch Mri Brain W And Wo Contrast/Tegmental (Capture) - 603',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-81 - Patient-81/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1306',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-82 - Patient-82/Mr Brain Wandwo Contrast/MCT2w192-R3 - 702',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-82 - Patient-82/Mr Brain Wandwo Contrast/Projection Images - 503',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-82 - Patient-82/Mr Brain Wandwo Contrast/Projection Images - 504',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-82 - Patient-82/Mr Brain Wandwo Contrast/Projection Images - 505',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-82 - Patient-82/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 2106',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-82 - Patient-82/Mr Brain Wandwo Contrast/T2w192-R3 - 702',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-83 - Patient-83/Mr Brain Reference Only/Study acquired outside hospital - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-84 - Patient-84/Mr Brain Wandwo Contrast/3Plane Loc SSFSE - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-85 - Patient-85/Mr Brain Reference Only/Study acquired outside hospital - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-86 - Patient-86/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1206',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-87 - Patient-87/Mr Brain Wandwo Contrast/Processed Images - 500',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-87 - Patient-87/Mr Brain Wandwo Contrast/Processed Images - 501',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-87 - Patient-87/Mr Brain Wandwo Contrast/Processed Images - 502',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-87 - Patient-87/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1206',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-87 - Patient-87/Mr Brain Wandwo Contrast/SCREENSAVE - 1000',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-89 - Patient-89/Mr Brain Wandwo Contrast/MCisoDWI192-R3 - 702',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-89 - Patient-89/Mr Brain Wandwo Contrast/Projection Images - 1001',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-89 - Patient-89/Mr Brain Wandwo Contrast/Projection Images - 603',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-89 - Patient-89/Mr Brain Wandwo Contrast/Projection Images - 604',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-89 - Patient-89/Mr Brain Wandwo Contrast/Projection Images - 605',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-89 - Patient-89/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1506',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-89 - Patient-89/Mr Brain Wandwo Contrast/T2w192-R3 - 702',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-90 - Patient-90/Mr Brain Reference Only/Localizers - 101',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-90 - Patient-90/Mr Brain Reference Only/MRI BRAIN WITHOUT CONT - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-90 - Patient-90/Mr Brain Reference Only/Study acquired outside hospital - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-92 - Patient-92/Lpch Mri Brain W And Wo Contrast/MCT2w132-R3 - 1002',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-93 - Patient-93/Mr Brain Wandwo Contrast/SCREENSAVE - 1100',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-94 - Patient-94/Mr Brain Wandwo Contrast/3D Lab- VR Movie - Mass-Brain Relationship - 150',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-94 - Patient-94/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1106',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-94 - Patient-94/Mr Brain Wandwo Contrast/SCREENSAVE - 1000',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-96 - Patient-96/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1206',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-98 - Patient-98/Mr Brain Wandwo Contrast/RAPID DWI and PWI Mismatch Lesion Sizes (colored) - 1306',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-99 - Patient-99/Mr Brain Reference Only/Study acquired outside hospital - 1',
#  '/labs/gevaertlab/data/radiology/StanfordGBM/2018-03-05/GBM/Patient-99 - Patient-99/Mr Brain Reference Only/unnamed - 99999']

# %%
csv_path = '/home/romains/stanford_gbm_v3.csv'

# %%
# save csv on disk to export to speadsheet after and check results
with open(csv_path, 'w') as csvfile:
    fieldnames = ['id', 'description', 'view', 'modality',\
                  'nb_dicoms', 'date', 'thickness', 'rows', 'columns', 'raw']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for k, folder in enumerate(all_files_path):
        if k % 300 == 0:
            print('file %d out of %d'%(k + 1, len(all_files_path)))
        try:
            patient_id, view, modality, date, thickness, rows,\
                columns, nb_dicoms, description = collect_info_patient_folder(folder)
        except:
            continue
        writer.writerow({'id': patient_id, 'description': description,\
                         'view': view, 'modality': modality, 'nb_dicoms': nb_dicoms,\
                         'date': date, 'thickness': thickness, 'rows': rows,\
                         'columns': columns, 'raw': folder})
# Out:
# file 1 out of 2315
# file 301 out of 2315
# file 601 out of 2315
# file 901 out of 2315
# file 1201 out of 2315
# file 1501 out of 2315
# file 1801 out of 2315
# file 2101 out of 2315

# %%
# load csv to run some analyses on the number of patients for each view/modality
df = pd.read_csv(csv_path)

# drop any row for which view is not axial
df3 = df.replace('sagital', pd.np.nan)
df3 = df3.replace('coronal', pd.np.nan)
df3 = df3.dropna(axis=0, how='any')

# %%
df.modality.unique()
# Out:
# array([nan, 'dwi', 'flair', 'gre', 't1post', 't1pre', 't2',
#        'multiple modalities detected', 't1 pre or post?'], dtype=object)

# %%
df.shape
# Out:
# (2200, 10)

# %%
dfpivot = df3.loc[:,['id', 'modality', 'nb_dicoms', 'date']]
# TODO: figure out which folder to keep in case one patient has several folders for the same view and modality
dfpivot = dfpivot.sort_values(by=['date'])
dfpivot.drop_duplicates(subset=['id', 'modality'], keep='first', inplace=True)
dfpivot = dfpivot.loc[:, ['id', 'modality', 'nb_dicoms']]
dfpivot = dfpivot.set_index(['id', 'modality'])
dfpivot = dfpivot.unstack(fill_value=0)
dfpivot = dfpivot.loc[:, 'nb_dicoms']

dfpivot
# Out:
# modality     dwi  flair  gre  multiple modalities detected  t1 pre or post?  \
# id
# Patient-01    60     52   30                             0                0
# Patient-02    64     52   31                             0                0
# Patient-03     0     24    0                            24               24
# Patient-04    62     52   32                             0                0
# Patient-05     0     36    0                            36               36
# Patient-06   176     68    0                             0               68
# Patient-07    48     49   24                             0               24
# Patient-08    26     26    0                            26                0
# Patient-09    54      0    0                            27               27
# Patient-10    40     43    0                             0               43
# Patient-100    0     26   26                             0                0
# Patient-11    60     49   30                             0                0
# Patient-13    60     51   30                             0                0
# Patient-14    60     52   30                             0                0
# Patient-15     0      0    0                             0               26
# Patient-16    56      0    0                             0               55
# Patient-17     0     26    0                             0               26
# Patient-18    60     52   30                             0                0
# Patient-19     0      0    0                             0                0
# Patient-20    56     29   29                             0                0
# Patient-21    64     32    0                             0               30
# Patient-22    60    121   30                             0                0
# Patient-24    64     25    0                            25                0
# Patient-25    46     49   23                             0               23
# Patient-26    58     27    0                            27               27
# Patient-27    64     32   32                             0                0
# Patient-28     0      0    0                             0                0
# Patient-29    26     26    0                            26                0
# Patient-30    44     22   22                             0               22
# Patient-31    62      0   25                            25                0
# ...          ...    ...  ...                           ...              ...
# Patient-66    70     41    0                            41              121
# Patient-67     0     23   23                            23                0
# Patient-68     0     24    0                             0               24
# Patient-69     0     22    0                             0               22
# Patient-70     0     22   23                             0               92
# Patient-71     0     25    0                             0               25
# Patient-72     0     24    0                             0                0
# Patient-73    60     30   30                             0                0
# Patient-74     0      0    0                             0                0
# Patient-75     0      0    0                             0                0
# Patient-76    60     30   30                             0                0
# Patient-81     0     23   23                             0                0
# Patient-82    60     30   30                             0                0
# Patient-83     0     24    0                             0               84
# Patient-84    60     30   30                             0                0
# Patient-85    25     25    0                             0               25
# Patient-86    56    121   28                             0                0
# Patient-87     0     22   22                             0              100
# Patient-88     0      0    0                             0               85
# Patient-89    60     30   30                             0                0
# Patient-90     0     24    0                             0                0
# Patient-91    60     30   30                            30                0
# Patient-92    76     28    0                             0                0
# Patient-93    64     32   32                             0               32
# Patient-94    60     30   30                             0                0
# Patient-95     0      0    0                             0                0
# Patient-96    60     30   30                            30               90
# Patient-97    60     30   30                            30               92
# Patient-98     0     21   21                             0                0
# Patient-99     0      0    0                            26                0
#
# modality     t1post  t1pre  t2
# id
# Patient-01       30     30  30
# Patient-02       31     13  32
# Patient-03       24      0  24
# Patient-04       32     32  32
# Patient-05       32     32   0
# Patient-06        0      0  68
# Patient-07       24      0  24
# Patient-08        0      0  26
# Patient-09       27      0   0
# Patient-10       43      0  43
# Patient-100      92     52  26
# Patient-11       30     30  30
# Patient-13       30     30  30
# Patient-14       30     30  30
# Patient-15       26      0  26
# Patient-16       24      0  55
# Patient-17       26      0  26
# Patient-18       30     30  30
# Patient-19       22      0  56
# Patient-20      120    120  29
# Patient-21       30      0  45
# Patient-22       30     30  30
# Patient-24        0      0  25
# Patient-25       23      0  23
# Patient-26       27      0  27
# Patient-27       32     32  32
# Patient-28       26     26  26
# Patient-29        0      0  26
# Patient-30       22      0  22
# Patient-31        0      0   0
# ...             ...    ...  ..
# Patient-66       74      0   0
# Patient-67        0      0   0
# Patient-68       24      0  24
# Patient-69       22      0  22
# Patient-70       23     23  23
# Patient-71       25      0  25
# Patient-72       34     34  29
# Patient-73       30     30  30
# Patient-74        0      0  84
# Patient-75        0      0  84
# Patient-76       30     30  30
# Patient-81       23      0  23
# Patient-82       95      0  30
# Patient-83        0      0   0
# Patient-84       30     30  30
# Patient-85       25      0  25
# Patient-86       28     28  28
# Patient-87       22     22  22
# Patient-88        0      0   0
# Patient-89       30      0  30
# Patient-90        0      0  24
# Patient-91       31     15  30
# Patient-92       28      0  28
# Patient-93       32      0  32
# Patient-94       30     30  30
# Patient-95       93      0   0
# Patient-96       88      0  30
# Patient-97       30      0  30
# Patient-98       21     21  21
# Patient-99       52     52   0
#
# [87 rows x 8 columns]

# %%
dfpivot.loc[(dfpivot.flair > 0)].shape
dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0)].shape
dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0) & (dfpivot.flair == dfpivot.t1post)].shape
# dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0) & (dfpivot.t1pre > 0) & (dfpivot.t2 > 0)].shape
#Counter(dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0) & (dfpivot.flair == dfpivot.t1post)].flair)
# dfpivot.loc[(dfpivot.flair > 0) & (dfpivot.t1post > 0) | (dfpivot.flair > 0) & (dfpivot["t1 pre or post?"] > 0)]
# dfpivot.loc[dfpivot.flair > 0]
# Out:
# (29, 8)

# %%
# list of descriptions for which we can't classify between T1 post and T1 pre or mutliple modalities
df4 = df3[df3.modality == "t1 pre or post?"]
#df4 = df3[df3.modality == "multiple modalities detected"]
df4.drop_duplicates(subset=['description'], keep='first', inplace=True)
df4.loc[:, ['description', 'raw']]
df4.description.tolist()
#list(np.unique(np.array(sorted(list(df3[df3.modality == "t1 pre or post?"].description)))))
# Out:
# /home/romains/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# ['AX T1',
#  'AX T1 SE',
#  'Ax T1',
#  'AXIAL T1 SE',
#  'AX T1 FLASH',
#  'AX T1 FFE',
#  'AX T1 FSE',
#  'AX T1 Variable flip SE',
#  'AX T1 SE STEREO WB+C',
#  'K:AX T1W',
#  'Ax T1 Variable flip SE',
#  'AX T1 STEREO',
#  'H2:AX T1',
#  'AX T1 STEREO+C']
